# %% [markdown]
# # 2 Data Wrangling
#
# ## 2.1 Imports and Set Display

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2.2 Load Datasets

# %% [markdown]
# the dataset RealEstData08102023.csv can be download from wake county real estate website:
# https://www.wake.gov/departments-government/tax-administration/data-files-statistics-and-reports/real-estate-property-data-files
# or
# https://drive.google.com/file/d/1tJGIx7okHZGMb_5y3FYzY6btbYtpT4wZ/view?usp=drive_link

# %%
# load datasets
house = pd.read_csv('../Data/RealEstData08102023.csv')

# %% [markdown]
# ## 2.3 Data Cleaning

# %% [markdown]
# ### 2.3.1 Shape and Columns

# %%
# check shape, rows and columns
house.shape
# Out:
# (441329, 87)

# %%
house.head()
# Out:
#                       OWNER1 OWNER2              Mailing_address1  \
# 0   NORTHGATE PROPERTIES LLC    NaN                8465 LENTIC CT
# 1               BONES 13 LLC    NaN             306 MIDENHALL WAY
# 2               BONES 13 LLC    NaN             306 MIDENHALL WAY
# 3  HARRISPARK PROPERTIES INC    NaN         608 GASTON ST STE 200
# 4             MOGHADASS, INC    NaN  1532 PROVIDENCE RD S STE 230
#
#         Mailing_Address2 Mailing_Address3  REAL_ESTATE_ID  CARD_NUMBER  \
# 0  RALEIGH NC 27615-4964              NaN               1            1
# 1     CARY NC 27513-5569              NaN               3            1
# 2     CARY NC 27513-5569              NaN               3            2
# 3  RALEIGH NC 27603-1258              NaN               4            1
# 4   WAXHAW NC 28173-8313              NaN               5            1
#
#    NUMBER_OF_CARDS  Street_Number Street_Prefix  Street_Name Street_Type  \
# 0                1           1506           NaN  WAKE FOREST          RD
# 1                2           6012           NaN     TRIANGLE          DR
# 2                2           6012           NaN     TRIANGLE          DR
# 3                1           1601           NaN  WAKE FOREST          RD
# 4                1           1831           NaN      CAPITAL        BLVD
#
#   Street_Suffix Planning_Jurisdiction Street_Misc  Township  Fire_District  \
# 0           NaN                    RA         NaN         1            NaN
# 1           NaN                    RA           A         8            NaN
# 2           NaN                    RA         NaN         8            NaN
# 3           NaN                    RA         NaN         1            NaN
# 4           NaN                    RA         NaN         1            NaN
#
#   Land_Sale_Price Land_Sale_Date Zoning  Deeded_Acreage Total_sale_Price  \
# 0               0            NaN   NX-3            0.32                0
# 1               0            NaN   IX-3            2.00          740,000
# 2               0            NaN   IX-3            2.00          740,000
# 3               0            NaN   IX-3            1.38          185,000
# 4               0            NaN   IX-3            1.11          750,000
#
#   Total_Sale_Date Assessed_Building_Value Assessed_Land_Value  \
# 0             NaN                       0             112,906
# 1          3/5/12                 524,503             392,040
# 2          3/5/12                 524,503             392,040
# 3         10/8/84                 374,128             245,076
# 4         6/17/16                 238,511             578,774
#
#   Parcel_Identification Special_District1  Special_District2  \
# 0   1714.09 05 9993 000               NaN                NaN
# 1   0778.03 40 5654 000               NaN                NaN
# 2   0778.03 40 5654 000               NaN                NaN
# 3   1714.09 06 7476 000               NaN                NaN
# 4   1714.06 38 2057 000               NaN                NaN
#
#    Special_District3  BILLING_CLASS  \
# 0                NaN              1
# 1                NaN              1
# 2                NaN              1
# 3                NaN              1
# 4                NaN              1
#
#                         PROPERTY_DESCRIPTION Land_classification DEED_BOOK  \
# 0         1506 WAKE FOREST ROAD BM1974-00494                   V     18105
# 1             LO7 OLD SOUTH DEVELOPMENT CORP                   C     14675
# 2             LO7 OLD SOUTH DEVELOPMENT CORP                   C     14675
# 3  LO2 PROP HARRIS WHOLESALE INC BM1988-1500                   C     SEC-S
# 4      ADJ FAIRFIELD MOTEL EDWARDS PLOT TR32                   C     16425
#
#   DEED_PAGE Deed_Date      VCS                         PROPERTY_INDEX  \
# 0      0863   9/30/20  ECRA001                                ECRA001
# 1      2635    3/5/12  GWRA001                            J W BURRESS
# 2      2635    3/5/12  GWRA001                       BLUE LINE RENTAL
# 3      TATE   1/19/11  ECRA001  A-ONE GLASS, AUTO AIR/RANDY'S PAINT &
# 4      1667   6/17/16  ECRA001                          ALL DAY TIRES
#
#    Year_Built  NUM_of_Rooms  UNITS  HEATED_AREA UTILITIES  Street_pavement  \
# 0           0             0      0            0       ALL              NaN
# 1        1979             0      0         4500       ALL              NaN
# 2        1989             0      0         4008       ALL              NaN
# 3        1993             0      0         8500       ALL              NaN
# 4        1968             0      0         3088       ALL              NaN
#
#    TOPOGRAPHY  Year_of_Addition  Effective_year  Remodeled_Year  \
# 0         NaN                 0               0               0
# 1         NaN                 0            1984               0
# 2         NaN                 0            1989               0
# 3         NaN                 0            1993               0
# 4         NaN                 0            1980               0
#
#   Special_Write_In Story_Height DESIGN_STYLE Foundation_Basement  \
# 0              NaN          NaN          NaN                 NaN
# 1              NaN            A            A                   D
# 2              NaN            A            A                   D
# 3              NaN            A            A                   D
# 4              NaN            A            A                 NaN
#
#    Foundation_Basement_Percent Exterior_Wall  COMMON_WALL  ROOF  \
# 0                            0           NaN          NaN   NaN
# 1                            0             O          NaN   NaN
# 2                            0             B          NaN   NaN
# 3                            0             O          NaN   NaN
# 4                            0             B          NaN   NaN
#
#   Roof_Floor_System  Floor_Finish  Interior_Finish  Interior_Finish1  \
# 0               NaN           NaN              NaN               NaN
# 1                 C           NaN              NaN               NaN
# 2                 C           NaN              NaN               NaN
# 3                 C           NaN              NaN               NaN
# 4                 C           NaN              NaN               NaN
#
#    Interior_Finish1_percent  Interior_Finish2  Interior_Finish2_percent HEAT  \
# 0                       NaN               NaN                       NaN  NaN
# 1                       NaN               NaN                       NaN    G
# 2                       NaN               NaN                       NaN    A
# 3                       NaN               NaN                       NaN    G
# 4                       NaN               NaN                       NaN    A
#
#    HEAT_PERCENT  AIR  AIR_PERCENT BATH  BATH_FIXTURES Built_in1_Description  \
# 0             0  NaN            0  NaN              0                   NaN
# 1             0    A           10    I              0                   NaN
# 2             0    A            0    I              0                   NaN
# 3             0    A           12    I              0                   NaN
# 4             0    A            0    I              0                   NaN
#
#   Built_in2_Description Built_in3_Description Built_in4_Description  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   Built_in5_Description CITY  GRADE  Assessed_Grade_Difference  \
# 0                   NaN  RAL    NaN                          0
# 1                   NaN  RAL  29.61                        110
# 2                   NaN  RAL  25.61                        110
# 3                   NaN  RAL  41.61                        110
# 4                   NaN  RAL  29.55                        100
#
#    Accrued_Assessed_Condition_Pct Land_Deferred_code  Land_Deferred_Amount  \
# 0                               0                NaN                     0
# 1                              47                NaN                     0
# 2                              55                NaN                     0
# 3                              45                NaN                     0
# 4                              44                NaN                     0
#
#   Historic_Deferred_code  Historic_Deferred_Amount  RECYCLED_UNITS  \
# 0                    NaN                         0               0
# 1                    NaN                         0               0
# 2                    NaN                         0               0
# 3                    NaN                         0               0
# 4                    NaN                         0               0
#
#   Disq_and_Qual_flag Land_Disq_and_Qual_flag  TYPE_AND_USE PHYSICAL_CITY  \
# 0                NaN                     NaN           NaN       RALEIGH
# 1                  A                     NaN          20.0       RALEIGH
# 2                  A                     NaN          34.0       RALEIGH
# 3                  T                     NaN          85.0       RALEIGH
# 4                  A                     NaN         200.0       RALEIGH
#
#    PHYSICAL_ZIP_CODE
# 0            27604.0
# 1            27617.0
# 2            27617.0
# 3            27604.0
# 4            27604.0

# %%
house.columns
# Out:
# Index(['OWNER1', 'OWNER2', 'Mailing_address1', 'Mailing_Address2',
#        'Mailing_Address3', 'REAL_ESTATE_ID', 'CARD_NUMBER', 'NUMBER_OF_CARDS',
#        'Street_Number', 'Street_Prefix', 'Street_Name', 'Street_Type',
#        'Street_Suffix', 'Planning_Jurisdiction', 'Street_Misc', 'Township',
#        'Fire_District', 'Land_Sale_Price', 'Land_Sale_Date', 'Zoning',
#        'Deeded_Acreage', 'Total_sale_Price', 'Total_Sale_Date',
#        'Assessed_Building_Value', 'Assessed_Land_Value',
#        'Parcel_Identification', 'Special_District1', 'Special_District2',
#        'Special_District3', 'BILLING_CLASS', 'PROPERTY_DESCRIPTION',
#        'Land_classification', 'DEED_BOOK', 'DEED_PAGE', 'Deed_Date', 'VCS',
#        'PROPERTY_INDEX', 'Year_Built', 'NUM_of_Rooms', 'UNITS', 'HEATED_AREA',
#        'UTILITIES', 'Street_pavement', 'TOPOGRAPHY', 'Year_of_Addition',
#        'Effective_year', 'Remodeled_Year', 'Special_Write_In', 'Story_Height',
#        'DESIGN_STYLE', 'Foundation_Basement', 'Foundation_Basement_Percent',
#        'Exterior_Wall', 'COMMON_WALL', 'ROOF', 'Roof_Floor_System',
#        'Floor_Finish', 'Interior_Finish', 'Interior_Finish1',
#        'Interior_Finish1_percent', 'Interior_Finish2',
#        'Interior_Finish2_percent', 'HEAT', 'HEAT_PERCENT', 'AIR',
#        'AIR_PERCENT', 'BATH', 'BATH_FIXTURES', 'Built_in1_Description',
#        'Built_in2_Description', 'Built_in3_Description',
#        'Built_in4_Description', 'Built_in5_Description', 'CITY', 'GRADE',
#        'Assessed_Grade_Difference', 'Accrued_Assessed_Condition_Pct',
#        'Land_Deferred_code', 'Land_Deferred_Amount', 'Historic_Deferred_code',
#        'Historic_Deferred_Amount', 'RECYCLED_UNITS', 'Disq_and_Qual_flag',
#        'Land_Disq_and_Qual_flag', 'TYPE_AND_USE', 'PHYSICAL_CITY',
#        'PHYSICAL_ZIP_CODE'],
#       dtype='object')

# %% [markdown]
# change all columns names to lowercase

# %%
house.columns = [i.lower() for i in list(house.columns)]
house.head()
# Out:
#                       owner1 owner2              mailing_address1  \
# 0   NORTHGATE PROPERTIES LLC    NaN                8465 LENTIC CT
# 1               BONES 13 LLC    NaN             306 MIDENHALL WAY
# 2               BONES 13 LLC    NaN             306 MIDENHALL WAY
# 3  HARRISPARK PROPERTIES INC    NaN         608 GASTON ST STE 200
# 4             MOGHADASS, INC    NaN  1532 PROVIDENCE RD S STE 230
#
#         mailing_address2 mailing_address3  real_estate_id  card_number  \
# 0  RALEIGH NC 27615-4964              NaN               1            1
# 1     CARY NC 27513-5569              NaN               3            1
# 2     CARY NC 27513-5569              NaN               3            2
# 3  RALEIGH NC 27603-1258              NaN               4            1
# 4   WAXHAW NC 28173-8313              NaN               5            1
#
#    number_of_cards  street_number street_prefix  street_name street_type  \
# 0                1           1506           NaN  WAKE FOREST          RD
# 1                2           6012           NaN     TRIANGLE          DR
# 2                2           6012           NaN     TRIANGLE          DR
# 3                1           1601           NaN  WAKE FOREST          RD
# 4                1           1831           NaN      CAPITAL        BLVD
#
#   street_suffix planning_jurisdiction street_misc  township  fire_district  \
# 0           NaN                    RA         NaN         1            NaN
# 1           NaN                    RA           A         8            NaN
# 2           NaN                    RA         NaN         8            NaN
# 3           NaN                    RA         NaN         1            NaN
# 4           NaN                    RA         NaN         1            NaN
#
#   land_sale_price land_sale_date zoning  deeded_acreage total_sale_price  \
# 0               0            NaN   NX-3            0.32                0
# 1               0            NaN   IX-3            2.00          740,000
# 2               0            NaN   IX-3            2.00          740,000
# 3               0            NaN   IX-3            1.38          185,000
# 4               0            NaN   IX-3            1.11          750,000
#
#   total_sale_date assessed_building_value assessed_land_value  \
# 0             NaN                       0             112,906
# 1          3/5/12                 524,503             392,040
# 2          3/5/12                 524,503             392,040
# 3         10/8/84                 374,128             245,076
# 4         6/17/16                 238,511             578,774
#
#   parcel_identification special_district1  special_district2  \
# 0   1714.09 05 9993 000               NaN                NaN
# 1   0778.03 40 5654 000               NaN                NaN
# 2   0778.03 40 5654 000               NaN                NaN
# 3   1714.09 06 7476 000               NaN                NaN
# 4   1714.06 38 2057 000               NaN                NaN
#
#    special_district3  billing_class  \
# 0                NaN              1
# 1                NaN              1
# 2                NaN              1
# 3                NaN              1
# 4                NaN              1
#
#                         property_description land_classification deed_book  \
# 0         1506 WAKE FOREST ROAD BM1974-00494                   V     18105
# 1             LO7 OLD SOUTH DEVELOPMENT CORP                   C     14675
# 2             LO7 OLD SOUTH DEVELOPMENT CORP                   C     14675
# 3  LO2 PROP HARRIS WHOLESALE INC BM1988-1500                   C     SEC-S
# 4      ADJ FAIRFIELD MOTEL EDWARDS PLOT TR32                   C     16425
#
#   deed_page deed_date      vcs                         property_index  \
# 0      0863   9/30/20  ECRA001                                ECRA001
# 1      2635    3/5/12  GWRA001                            J W BURRESS
# 2      2635    3/5/12  GWRA001                       BLUE LINE RENTAL
# 3      TATE   1/19/11  ECRA001  A-ONE GLASS, AUTO AIR/RANDY'S PAINT &
# 4      1667   6/17/16  ECRA001                          ALL DAY TIRES
#
#    year_built  num_of_rooms  units  heated_area utilities  street_pavement  \
# 0           0             0      0            0       ALL              NaN
# 1        1979             0      0         4500       ALL              NaN
# 2        1989             0      0         4008       ALL              NaN
# 3        1993             0      0         8500       ALL              NaN
# 4        1968             0      0         3088       ALL              NaN
#
#    topography  year_of_addition  effective_year  remodeled_year  \
# 0         NaN                 0               0               0
# 1         NaN                 0            1984               0
# 2         NaN                 0            1989               0
# 3         NaN                 0            1993               0
# 4         NaN                 0            1980               0
#
#   special_write_in story_height design_style foundation_basement  \
# 0              NaN          NaN          NaN                 NaN
# 1              NaN            A            A                   D
# 2              NaN            A            A                   D
# 3              NaN            A            A                   D
# 4              NaN            A            A                 NaN
#
#    foundation_basement_percent exterior_wall  common_wall  roof  \
# 0                            0           NaN          NaN   NaN
# 1                            0             O          NaN   NaN
# 2                            0             B          NaN   NaN
# 3                            0             O          NaN   NaN
# 4                            0             B          NaN   NaN
#
#   roof_floor_system  floor_finish  interior_finish  interior_finish1  \
# 0               NaN           NaN              NaN               NaN
# 1                 C           NaN              NaN               NaN
# 2                 C           NaN              NaN               NaN
# 3                 C           NaN              NaN               NaN
# 4                 C           NaN              NaN               NaN
#
#    interior_finish1_percent  interior_finish2  interior_finish2_percent heat  \
# 0                       NaN               NaN                       NaN  NaN
# 1                       NaN               NaN                       NaN    G
# 2                       NaN               NaN                       NaN    A
# 3                       NaN               NaN                       NaN    G
# 4                       NaN               NaN                       NaN    A
#
#    heat_percent  air  air_percent bath  bath_fixtures built_in1_description  \
# 0             0  NaN            0  NaN              0                   NaN
# 1             0    A           10    I              0                   NaN
# 2             0    A            0    I              0                   NaN
# 3             0    A           12    I              0                   NaN
# 4             0    A            0    I              0                   NaN
#
#   built_in2_description built_in3_description built_in4_description  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   built_in5_description city  grade  assessed_grade_difference  \
# 0                   NaN  RAL    NaN                          0
# 1                   NaN  RAL  29.61                        110
# 2                   NaN  RAL  25.61                        110
# 3                   NaN  RAL  41.61                        110
# 4                   NaN  RAL  29.55                        100
#
#    accrued_assessed_condition_pct land_deferred_code  land_deferred_amount  \
# 0                               0                NaN                     0
# 1                              47                NaN                     0
# 2                              55                NaN                     0
# 3                              45                NaN                     0
# 4                              44                NaN                     0
#
#   historic_deferred_code  historic_deferred_amount  recycled_units  \
# 0                    NaN                         0               0
# 1                    NaN                         0               0
# 2                    NaN                         0               0
# 3                    NaN                         0               0
# 4                    NaN                         0               0
#
#   disq_and_qual_flag land_disq_and_qual_flag  type_and_use physical_city  \
# 0                NaN                     NaN           NaN       RALEIGH
# 1                  A                     NaN          20.0       RALEIGH
# 2                  A                     NaN          34.0       RALEIGH
# 3                  T                     NaN          85.0       RALEIGH
# 4                  A                     NaN         200.0       RALEIGH
#
#    physical_zip_code
# 0            27604.0
# 1            27617.0
# 2            27617.0
# 3            27604.0
# 4            27604.0

# %%
house = house[(house['type_and_use']==1.0)|(house['type_and_use']==2.0)\
|(house['type_and_use']==3.0)|(house['type_and_use']==4.0)]
house.shape
# Out:
# (352226, 87)

# %% [markdown]
# ### 2.3.2 Check Variables total_sale_price and total_sale_date
# #### 2.3.2.1 total_sale_price

# %%
house['total_sale_price'].unique()
# Out:
# array(['34,500', '35,500', '0', ..., '1,285,500', '1,304,500',
#        '1,186,500'], dtype=object)

# %%
# remove , in values
# change to numeric
house['total_sale_price'] = house['total_sale_price'].str.replace(',','')
house['total_sale_price'] = pd.to_numeric(house['total_sale_price'], errors = 'coerce')

# %%
house = house[house['total_sale_price'].notna()]
house.shape
# Out:
# (352226, 87)

# %% [markdown]
# no rows deleted! check the statistics

# %%
house.total_sale_price.describe()
# Out:
# count    3.522260e+05
# mean     2.923822e+05
# std      5.180879e+05
# min      0.000000e+00
# 25%      1.450000e+05
# 50%      2.500000e+05
# 75%      3.850000e+05
# max      8.350000e+07
# Name: total_sale_price, dtype: float64

# %% [markdown]
# the minimum total_sale_price is 0, doesn't make sense. check it.

# %%
house[house['total_sale_price']==0].shape
# Out:
# (22407, 87)

# %%
house[house['total_sale_price']==0].head()
# Out:
#                          owner1 owner2     mailing_address1  \
# 10         WOMBLE, GEORGE M III    NaN        2124 RIDGE RD
# 15               ABBOTT, HUBERT    NaN      605 WOODLAND RD
# 35  TILLEY, BETTY WELLS TRUSTEE    NaN      408 GERANIUM CT
# 44            CAVALIERO, MARK L    NaN  3217 COLBY CHASE DR
# 59   MEJIA, RAMON ALBERTO SUAZO    NaN         PO BOX 14968
#
#                mailing_address2 mailing_address3  real_estate_id  card_number  \
# 10        RALEIGH NC 27607-3148              NaN              21            1
# 15        RALEIGH NC 27603-4741              NaN              26            1
# 35  FUQUAY VARINA NC 27526-2366              NaN              48            1
# 44           APEX NC 27539-3639              NaN              59            1
# 59        RALEIGH NC 27620-4968              NaN              74            1
#
#     number_of_cards  street_number street_prefix street_name street_type  \
# 10                1            409             S    LAKESIDE          DR
# 15                1            605           NaN    WOODLAND          RD
# 35                1            105           NaN     CLIFTON          ST
# 44                1           2109           NaN    HENSLOWE          DR
# 59                1           6123           NaN       POOLE          RD
#
#    street_suffix planning_jurisdiction street_misc  township  fire_district  \
# 10           NaN                    RA         NaN         1            NaN
# 15           NaN                    GA         NaN        16           23.0
# 35           NaN                    FV         NaN        12            NaN
# 44           NaN                    RA         NaN        18            NaN
# 59           NaN                    RA         NaN        17           23.0
#
#    land_sale_price land_sale_date zoning  deeded_acreage  total_sale_price  \
# 10          28,000        3/26/99    R-4            0.43                 0
# 15               0            NaN     R2            0.51                 0
# 35               0            NaN    RLD            0.33                 0
# 44               0            NaN    R-4            0.38                 0
# 59               0            NaN    R-4            0.82                 0
#
#    total_sale_date assessed_building_value assessed_land_value  \
# 10             NaN                 132,624              90,000
# 15             NaN                  85,801              55,000
# 35             NaN                 115,531              55,000
# 44             NaN                  93,169              72,000
# 59             NaN                 218,042              49,500
#
#    parcel_identification special_district1  special_district2  \
# 10   0783.09 06 3610 000               NaN                NaN
# 15   1701.19 50 3123 000               NaN                NaN
# 35   0666.09 17 9443 000               NaN                NaN
# 44   1702.05 08 7284 000               NaN                NaN
# 59   1733.04 60 7337 000               NaN                NaN
#
#     special_district3  billing_class  \
# 10                NaN              2
# 15                NaN              2
# 35                NaN              2
# 44                NaN              2
# 59                NaN              2
#
#                         property_description land_classification deed_book  \
# 10                       LO38A ROYLENE ACRES                   R     13952
# 15                    LO24 ECHO HGTS SE3 BLE                   R     01264
# 35                            LO4 CLIFTON ST                   R     06923
# 44  LO2 RCMB CAROLINA PINES BLU BM2017-01671                   R     08328
# 59  LO18 RCMB RIVERVIEW ESTATES BM2010-00970                   R     13562
#
#    deed_page deed_date      vcs property_index  year_built  num_of_rooms  \
# 10      0809   5/26/10  01RA712        01RA712        1999             0
# 15      0626   2/25/57  16GA034        16GA034        1956             0
# 35      0873    4/9/96  12FV046        12FV046        1959             0
# 44      1267    6/4/99  18RA029        18RA029        1955             0
# 59      1309    6/2/09  17RA014        17RA014        1961             0
#
#     units  heated_area utilities  street_pavement  topography  \
# 10      1         1037       ALL              NaN         NaN
# 15      1          996         E              NaN         NaN
# 35      1         1344       WSE              NaN         NaN
# 44      1         1014       ALL              NaN         NaN
# 59      1         1978         E              NaN         NaN
#
#     year_of_addition  effective_year  remodeled_year special_write_in  \
# 10                 0            1999               0              NaN
# 15                 0            1970               0              NaN
# 35                 0            1974               0              NaN
# 44                 0            1970               0              NaN
# 59                 0            1991               0              NaN
#
#    story_height design_style foundation_basement  foundation_basement_percent  \
# 10            A            A                   D                            0
# 15            A            A                   D                            0
# 35            A            A                   A                            0
# 44            A            A                   D                            0
# 59            A            A                   D                            0
#
#    exterior_wall  common_wall  roof roof_floor_system  floor_finish  \
# 10             Z          NaN   NaN               NaN           NaN
# 15             Z          NaN   NaN               NaN           NaN
# 35             B          NaN   NaN               NaN           NaN
# 44             B          NaN   NaN               NaN           NaN
# 59             B          NaN   NaN               NaN           NaN
#
#     interior_finish  interior_finish1  interior_finish1_percent  \
# 10              NaN               NaN                       NaN
# 15              NaN               NaN                       NaN
# 35              NaN               NaN                       NaN
# 44              NaN               NaN                       NaN
# 59              NaN               NaN                       NaN
#
#     interior_finish2  interior_finish2_percent heat  heat_percent air  \
# 10               NaN                       NaN    A             0   A
# 15               NaN                       NaN    A             0   A
# 35               NaN                       NaN    A             0   A
# 44               NaN                       NaN    A             0   A
# 59               NaN                       NaN    A             0   A
#
#     air_percent bath  bath_fixtures built_in1_description  \
# 10            0    C              0                   NaN
# 15            0    A              0                   NaN
# 35            0    J              1                   NaN
# 44            0    A              0         One Fireplace
# 59            0    C              0                   NaN
#
#    built_in2_description built_in3_description built_in4_description  \
# 10                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 35                   NaN                   NaN                   NaN
# 44                   NaN                   NaN                   NaN
# 59                   NaN                   NaN                   NaN
#
#    built_in5_description city grade  assessed_grade_difference  \
# 10                   NaN  RAL  C+10                        110
# 15                   NaN  NaN     C                        100
# 35                   NaN  FUQ     C                        100
# 44                   NaN  RAL  C+05                        105
# 59                   NaN  NaN     C                        100
#
#     accrued_assessed_condition_pct land_deferred_code  land_deferred_amount  \
# 10                              83                NaN                     0
# 15                              64                NaN                     0
# 35                              69                NaN                     0
# 44                              67                NaN                     0
# 59                              79                NaN                     0
#
#    historic_deferred_code  historic_deferred_amount  recycled_units  \
# 10                    NaN                         0               1
# 15                    NaN                         0               1
# 35                    NaN                         0               1
# 44                    NaN                         0               1
# 59                    NaN                         0               1
#
#    disq_and_qual_flag land_disq_and_qual_flag  type_and_use  physical_city  \
# 10                NaN                       A           1.0        RALEIGH
# 15                NaN                     NaN           1.0        RALEIGH
# 35                NaN                     NaN           1.0  FUQUAY VARINA
# 44                NaN                     NaN           1.0        RALEIGH
# 59                NaN                     NaN           1.0        RALEIGH
#
#     physical_zip_code
# 10            27606.0
# 15            27603.0
# 35            27526.0
# 44            27603.0
# 59            27610.0

# %% [markdown]
# looks like the rows with total_sale_price is 0 also have null value in total_sale_date, check it

# %% [markdown]
# #### 2.3.2.2 total_sale_date

# %%
house['total_sale_date'].isna().sum()
# Out:
# 21972

# %% [markdown]
# check rows with null total_sale_date and 0 total_sale_price

# %%
((house['total_sale_date'].isna()) | (house['total_sale_price']==0)).sum()
# Out:
# 22421

# %% [markdown]
# drop these 22421 rows and recheck the shape

# %%
missing_date_value = house.loc[(house['total_sale_date'].isna()) | (house['total_sale_price']==0),:]

# %%
house = house.drop(missing_date_value.index)
house.shape
# Out:
# (329805, 87)

# %%
house['total_sale_date'].isna().sum()
# Out:
# 0

# %%
house[house['total_sale_price']==0].shape
# Out:
# (0, 87)

# %% [markdown]
# ### 2.3.3 Prepare physical_location and Check physical_zip_code
# #### 2.3.3.1 physical_location
# physical_location = street_number + street_prefix + street_name + street_type + street_suffix + street_misc

# %%
house['street_prefix'].unique()
# Out:
# array([nan, 'W', 'S', 'E', 'SE', 'N', 'SW', 'NW', 'NE'], dtype=object)

# %%
house['street_suffix'].unique()
# Out:
# array([nan, 'S', 'W', 'E', 'SW', 'N', 'SE'], dtype=object)

# %% [markdown]
# check one example

# %%
house[house['street_prefix']=='N'].head()
# Out:
#                        owner1            owner2   mailing_address1  \
# 79            RAWLS, GEORGE W               NaN  103 N SHETLAND CT
# 178              HEID, MARK D  HEID, PATRICIA A      533 N EAST ST
# 259            JONES, LATREKA               NaN      507 N GILL ST
# 410  ADAMS, KEVIN D & ERICA W               NaN   5703 N SHARON DR
# 511          ADAMS, WILLIAM E               NaN         PO BOX 429
#
#              mailing_address2 mailing_address3  real_estate_id  card_number  \
# 79       GARNER NC 27529-4540              NaN              95            1
# 178     RALEIGH NC 27604-1235              NaN             211            1
# 259     ZEBULON NC 27597-2743              NaN             314            1
# 410     RALEIGH NC 27603-4641              NaN             432            1
# 511  KNIGHTDALE NC 27545-0429              NaN             552            1
#
#      number_of_cards  street_number street_prefix street_name street_type  \
# 79                 1            103             N    SHETLAND          CT
# 178                1            533             N        EAST          ST
# 259                1            507             N        GILL          ST
# 410                1           5703             N      SHARON          DR
# 511                1            201             N  SMITHFIELD          RD
#
#     street_suffix planning_jurisdiction street_misc  township  fire_district  \
# 79            NaN                    GA         NaN        16            NaN
# 178           NaN                    RA         NaN         1            NaN
# 259           NaN                    ZB         NaN         9            NaN
# 410           NaN                    WC         NaN        16           23.0
# 511           NaN                    KN         NaN        17            NaN
#
#     land_sale_price land_sale_date zoning  deeded_acreage  total_sale_price  \
# 79                0            NaN     R4            0.32            245000
# 178               0            NaN   R-10            0.12            355000
# 259               0            NaN     R6            0.17            151000
# 410               0            NaN  R-40W            0.45             62600
# 511               0            NaN    GR3            0.39               500
#
#     total_sale_date assessed_building_value assessed_land_value  \
# 79          6/30/21                 134,621              63,000
# 178         3/31/05                 186,962             300,000
# 259         7/23/19                 137,895              28,000
# 410         8/27/18                 186,748              45,000
# 511          6/7/96                 126,770              48,600
#
#     parcel_identification special_district1  special_district2  \
# 79    1710.10 25 5742 000               NaN                NaN
# 178   1704.20 91 1803 000               NaN                NaN
# 259   2705.10 46 1863 000               NaN                NaN
# 410   0791.04 90 9449 000               NaN                NaN
# 511   1754.18 32 3413 000               NaN                NaN
#
#      special_district3  billing_class                    property_description  \
# 79                 NaN              2  LO49 HEATHER HLS PT SE1 BLA BM1969-189
# 178                NaN              2                                   LO114
# 259                NaN              2               LO59 GILL ST BM1885-00099
# 410                NaN              2         LO65 COLONIAL HGTS SUB BLD BM6-
# 511                NaN              2                       LO1 SMITHFIELD RD
#
#     land_classification deed_book deed_page deed_date      vcs property_index  \
# 79                    R     19383      1168   7/13/23  16GA027        16GA027
# 178                   R     11290      0331   3/31/05  01RA558        01RA558
# 259                   R     17513      1343   7/23/19  09ZB015        09ZB015
# 410                   R     17226      0084   8/27/18  16WC008        16WC008
# 511                   R       -E-         -    4/5/19  17KN900        17KN900
#
#      year_built  num_of_rooms  units  heated_area utilities  street_pavement  \
# 79         1968             0      1         1579       ALL              NaN
# 178        1925             0      1         1971       ALL              NaN
# 259        2018             0      1         1308       WSE              NaN
# 410        1965             0      1         3099         E              NaN
# 511        1940             0      1         1862       WSE              NaN
#
#      topography  year_of_addition  effective_year  remodeled_year  \
# 79          NaN                 0            1973               0
# 178         NaN                 0            1980               0
# 259         NaN                 0            2018               0
# 410         NaN              2020            1970               0
# 511         NaN              2015            1960               0
#
#     special_write_in story_height design_style foundation_basement  \
# 79               NaN            A            G                   D
# 178              NaN            A            A                   B
# 259              NaN            A            A                   D
# 410              NaN            A            A                   A
# 511              NaN            A            G                   D
#
#      foundation_basement_percent exterior_wall  common_wall  roof  \
# 79                             0             B          NaN   NaN
# 178                           40             A          NaN   NaN
# 259                            0             Z          NaN   NaN
# 410                            0             B          NaN   NaN
# 511                            0             Z          NaN   NaN
#
#     roof_floor_system  floor_finish  interior_finish  interior_finish1  \
# 79                NaN           NaN              NaN               NaN
# 178               NaN           NaN              NaN               NaN
# 259               NaN           NaN              NaN               NaN
# 410               NaN           NaN              NaN               NaN
# 511               NaN           NaN              NaN               NaN
#
#      interior_finish1_percent  interior_finish2  interior_finish2_percent  \
# 79                        NaN               NaN                       NaN
# 178                       NaN               NaN                       NaN
# 259                       NaN               NaN                       NaN
# 410                       NaN               NaN                       NaN
# 511                       NaN               NaN                       NaN
#
#     heat  heat_percent air  air_percent bath  bath_fixtures  \
# 79     A             0   A            0    B              0
# 178    A             0   A            0    C              0
# 259    A             0   A            0    C              0
# 410    A             0   A            0    D              0
# 511    A             0   A            0    A              0
#
#     built_in1_description built_in2_description built_in3_description  \
# 79                    NaN                   NaN                   NaN
# 178         One Fireplace                   NaN                   NaN
# 259                   NaN                   NaN                   NaN
# 410         One Fireplace                   NaN                   NaN
# 511       Multiple Firepl                   NaN                   NaN
#
#     built_in4_description built_in5_description city grade  \
# 79                    NaN                   NaN  GAR  C+05
# 178                   NaN                   NaN  RAL     B
# 259                   NaN                   NaN  ZEB  C-10
# 410                   NaN                   NaN  NaN     C
# 511                   NaN                   NaN  KNI     C
#
#      assessed_grade_difference  accrued_assessed_condition_pct  \
# 79                         105                              69
# 178                        120                              80
# 259                         90                              96
# 410                        100                              67
# 511                        100                              54
#
#     land_deferred_code  land_deferred_amount historic_deferred_code  \
# 79                 NaN                     0                    NaN
# 178                NaN                     0                    NaN
# 259                NaN                     0                    NaN
# 410                NaN                     0                    NaN
# 511                NaN                     0                    NaN
#
#      historic_deferred_amount  recycled_units disq_and_qual_flag  \
# 79                          0               1                  A
# 178                         0               1                  A
# 259                         0               1                  A
# 410                         0               1                  E
# 511                         0               1                  E
#
#     land_disq_and_qual_flag  type_and_use physical_city  physical_zip_code
# 79                      NaN           1.0        GARNER            27529.0
# 178                     NaN           1.0       RALEIGH            27604.0
# 259                     NaN           1.0       ZEBULON            27597.0
# 410                     NaN           1.0       RALEIGH            27603.0
# 511                     NaN           1.0    KNIGHTDALE            27545.0

# %%
house[house['street_suffix']=='E'].head()
# Out:
#                                     owner1                     owner2  \
# 32374            BROWN, EDITH HOPE JOHNSON  MASSEY, BELINDA A JOHNSON
# 43738                   MOONEYHAM, COLBY H         MOONEYHAM, TYLER A
# 53193      GARNER CHRISTIAN FELLOWSHIP INC                        NaN
# 63755  NORTH CAROLINA DEPARTMENT OF TRANSP                        NaN
# 76211       BECKWITH, APRIL L & GEOFFREY M                        NaN
#
#             mailing_address1       mailing_address2  \
# 32374   2121 US HIGHWAY 70 E   GARNER NC 27529-9422
# 43738      COLBY H MOONEYHAM   233 MARSH LANDING DR
# 53193             PO BOX 744   GARNER NC 27529-0744
# 63755  1546 MAIL SERVICE CTR  RALEIGH NC 27699-1500
# 76211  11701 APPALOOSA RUN E  RALEIGH NC 27613-7107
#
#                   mailing_address3  real_estate_id  card_number  \
# 32374                          NaN           36381            1
# 43738  HOLLY SPRINGS NC 27540-5509           49363            1
# 53193                          NaN           60016            1
# 63755                          NaN           71726            1
# 76211                          NaN           85906            1
#
#        number_of_cards  street_number street_prefix street_name street_type  \
# 32374                1           2121           NaN       US 70         HWY
# 43738                1           2325           NaN       US 70         HWY
# 53193                1           2032           NaN       US 70         HWY
# 63755                1           2100           NaN       US 70         HWY
# 76211                1          11701           NaN   APPALOOSA         RUN
#
#       street_suffix planning_jurisdiction street_misc  township  \
# 32374             E                    WC         NaN        16
# 43738             E                    WC         NaN        16
# 53193             E                    GA         NaN        16
# 63755             E                    GA         NaN        16
# 76211             E                    WC         NaN         2
#
#        fire_district land_sale_price land_sale_date zoning  deeded_acreage  \
# 32374           23.0               0            NaN     RA            0.50
# 43738           23.0               0            NaN   R-40            0.64
# 53193           23.0               0            NaN    CMX            3.00
# 63755           23.0       1,057,500        8/31/20    CMX            5.71
# 76211           23.0               0            NaN  R-40W            1.00
#
#        total_sale_price total_sale_date assessed_building_value  \
# 32374             14500          1/1/69                  55,788
# 43738             55000          8/7/90                  85,307
# 53193            416300         11/1/22                   9,616
# 63755             50000          1/1/74                   9,938
# 76211            370000         2/23/17                 301,063
#
#       assessed_land_value parcel_identification special_district1  \
# 32374              35,000   1730.04 74 0344 000               NaN
# 43738              32,500   1730.04 93 3243 000               NaN
# 53193             334,541   1730.04 64 0112 000               NaN
# 63755             636,744   1730.04 64 5000 000               NaN
# 76211             100,000   0880.04 73 6565 000               NaN
#
#        special_district2  special_district3  billing_class  \
# 32374                NaN                NaN              2
# 43738                NaN                NaN              2
# 53193                NaN                NaN              1
# 63755                NaN                NaN              3
# 76211                NaN                NaN              2
#
#                      property_description land_classification deed_book  \
# 32374                       LO1 GODWIN LD                   R     1199-
# 43738                 PLEASANT & BAUGH LD                   R     19-E-
# 53193                  LANE & MASSEY LAND                   R     19188
# 63755                    LANE & MASSEY LD                   E     18045
# 76211  LO2 BLACK HORSE RUN SE2 BM1973-413                   R     16701
#
#       deed_page deed_date      vcs property_index  year_built  num_of_rooms  \
# 32374         E   3/29/05  16GA900        16GA900        1960             0
# 43738      4403   12/1/19  16GA900        16GA900        1967             0
# 53193      1543   11/1/22  EWGA001        EWGA001        1965             0
# 63755      2486   8/31/20  EWGA001        EWGA001        1967             0
# 76211      2785   2/23/17  02WC022        02WC022        1983             0
#
#        units  heated_area utilities  street_pavement  topography  \
# 32374      1         1000         E              NaN         NaN
# 43738      1          960         E              NaN         NaN
# 53193      1         2982         E              NaN         NaN
# 63755      1         2209         E              NaN         NaN
# 76211      1         3142         E              NaN         NaN
#
#        year_of_addition  effective_year  remodeled_year special_write_in  \
# 32374                 0            1960               0              NaN
# 43738                 0            1967               0              NaN
# 53193                 0            1965               0              NaN
# 63755                 0            1967               0              NaN
# 76211                 0            1983               0              NaN
#
#       story_height design_style foundation_basement  \
# 32374            A            G                   D
# 43738            A            G                   D
# 53193            A            G                   A
# 63755            A            G                   B
# 76211            C            A                   D
#
#        foundation_basement_percent exterior_wall  common_wall  roof  \
# 32374                            0             B          NaN   NaN
# 43738                            0             B          NaN   NaN
# 53193                            0             B          NaN   NaN
# 63755                           70             B          NaN   NaN
# 76211                            0             A          NaN   NaN
#
#       roof_floor_system  floor_finish  interior_finish  interior_finish1  \
# 32374               NaN           NaN              NaN               NaN
# 43738               NaN           NaN              NaN               NaN
# 53193               NaN           NaN              NaN               NaN
# 63755               NaN           NaN              NaN               NaN
# 76211               NaN           NaN              NaN               NaN
#
#        interior_finish1_percent  interior_finish2  interior_finish2_percent  \
# 32374                       NaN               NaN                       NaN
# 43738                       NaN               NaN                       NaN
# 53193                       NaN               NaN                       NaN
# 63755                       NaN               NaN                       NaN
# 76211                       NaN               NaN                       NaN
#
#       heat  heat_percent air  air_percent bath  bath_fixtures  \
# 32374    A             0   A            0    A              0
# 43738    A             0   A            0    B              0
# 53193    A             0   A            0    C              0
# 63755    A             0   A            0    D              0
# 76211    A             0   A            0    J              6
#
#       built_in1_description built_in2_description built_in3_description  \
# 32374                   NaN                   NaN                   NaN
# 43738                   NaN                   NaN                   NaN
# 53193       Multiple Firepl                   NaN                   NaN
# 63755         One Fireplace                   NaN                   NaN
# 76211         One Fireplace                   NaN                   NaN
#
#       built_in4_description built_in5_description city grade  \
# 32374                   NaN                   NaN  NaN     C
# 43738                   NaN                   NaN  NaN     C
# 53193                   NaN                   NaN  NaN  C+10
# 63755                   NaN                   NaN  NaN  C+10
# 76211                   NaN                   NaN  NaN  B+10
#
#        assessed_grade_difference  accrued_assessed_condition_pct  \
# 32374                        100                              40
# 43738                        100                              59
# 53193                        110                               3
# 63755                        110                               3
# 76211                        128                              74
#
#       land_deferred_code  land_deferred_amount historic_deferred_code  \
# 32374                NaN                     0                    NaN
# 43738                NaN                     0                    NaN
# 53193                NaN                     0                    NaN
# 63755                NaN                     0                    NaN
# 76211                NaN                     0                    NaN
#
#        historic_deferred_amount  recycled_units disq_and_qual_flag  \
# 32374                         0               1                  A
# 43738                         0               1                  A
# 53193                         0               1                  K
# 63755                         0               0                  A
# 76211                         0               1                  A
#
#       land_disq_and_qual_flag  type_and_use physical_city  physical_zip_code
# 32374                     NaN           1.0        GARNER            27529.0
# 43738                     NaN           1.0        GARNER            27529.0
# 53193                     NaN           1.0        GARNER            27529.0
# 63755                       A           1.0        GARNER            27529.0
# 76211                     NaN           1.0       RALEIGH            27613.0

# %%
house['street_number'] = house['street_number'].fillna('')
house['street_prefix'] = house['street_prefix'].fillna('')
house['street_name'] = house['street_name'].fillna('')
house['street_type'] = house['street_type'].fillna('')
house['street_suffix'] = house['street_suffix'].fillna('')
house['street_misc'] = house['street_misc'].fillna('')

# %%
house['street_number'] = house['street_number'].astype('str')

# %%
house.head()
# Out:
#                             owner1 owner2    mailing_address1  \
# 8   MICKENS, ROBERT EARL & ANNIE M    NaN      2457 BERTIE DR
# 9   COREY, JAMES CURTIS & REGINA B    NaN  2848 PROVIDENCE RD
# 11       MILLETTE, DAVID P & TRACY    NaN    540 MARSHBURN RD
# 12                   E&M MERCH INC    NaN      1000 GOBLET LN
# 14    ABBOTT, GEORGE F & LILLIAN B    NaN      8712 W LAKE CT
#
#              mailing_address2 mailing_address3  real_estate_id  card_number  \
# 8       RALEIGH NC 27610-1730              NaN              19            1
# 9       RALEIGH NC 27610-5210              NaN              20            1
# 11      WENDELL NC 27591-9307              NaN              22            1
# 12  MORRISVILLE NC 27560-6686              NaN              23            1
# 14      RALEIGH NC 27613-7509              NaN              25            1
#
#     number_of_cards street_number street_prefix     street_name street_type  \
# 8                 1          2457                        BERTIE          DR
# 9                 1          2848                    PROVIDENCE          RD
# 11                1           540                     MARSHBURN          RD
# 12                1           208                JONES FRANKLIN          RD
# 14                1          8712             W            LAKE          CT
#
#    street_suffix planning_jurisdiction street_misc  township  fire_district  \
# 8                                   RA                     1            NaN
# 9                                   RA                    16            NaN
# 11                                  WE                    10           23.0
# 12                                  RA                     1            NaN
# 14                                  RA                     8           23.0
#
#    land_sale_price land_sale_date zoning  deeded_acreage  total_sale_price  \
# 8                0            NaN    R-4            0.21             34500
# 9                0            NaN    R-4            0.46             35500
# 11               0            NaN     R3            0.46             37500
# 12               0            NaN    R-6            0.79            210000
# 14               0            NaN    R-2            0.96             70000
#
#    total_sale_date assessed_building_value assessed_land_value  \
# 8           1/1/74                 134,321             115,000
# 9          5/18/83                 114,933              45,000
# 11         9/16/04                 118,723              32,000
# 12         6/27/18                 105,618             112,500
# 14          1/1/71                 358,290             140,000
#
#    parcel_identification special_district1  special_district2  \
# 8    1714.20 81 7084 000               NaN                NaN
# 9    1722.11 65 9239 000               NaN                NaN
# 11   1784.19 52 6263 000               NaN                NaN
# 12   0783.06 29 5049 000               NaN                NaN
# 14   0788.18 41 0924 000               NaN                NaN
#
#     special_district3  billing_class                  property_description  \
# 8                 NaN              2             LO22 LONGVIEW GARDENS BLR
# 9                 NaN              2          LO18 GREEN VALLEY BM1959-315
# 11                NaN              2                         MARSHBURN AVE
# 12                NaN              1  LO7-10 FAIRVIEW HLS BLC BM1945-00093
# 14                NaN              2          LO8 & 9 SPGDLE ESTS SE2 BM1-
#
#    land_classification deed_book deed_page deed_date      vcs property_index  \
# 8                    R     02266      0483    1/1/74  01RA512        01RA512
# 9                    R     05846      0677  10/28/93  16RA030        16RA030
# 11                   R     11017      1697   9/16/04  10WE022        10WE022
# 12                   R     17167      2551   6/27/18  01RA72M        01RA72M
# 14                   R     02034      0509    1/1/71  08RA017        08RA017
#
#     year_built  num_of_rooms  units  heated_area utilities  street_pavement  \
# 8         1964             0      1         1828       ALL              NaN
# 9         1970             0      1         1240         E              NaN
# 11        1900             0      1         2261       WSE              NaN
# 12        1916             0      2         2440       ALL              NaN
# 14        1971             0      1         3770       WGE              NaN
#
#     topography  year_of_addition  effective_year  remodeled_year  \
# 8          NaN                 0            1980               0
# 9          NaN                 0            1985               0
# 11         NaN                 0            1960               0
# 12         NaN                 0            1960               0
# 14         NaN                 0            1971               0
#
#    special_write_in story_height design_style foundation_basement  \
# 8               NaN            A            I                   B
# 9               NaN            A            A                   D
# 11              NaN            A            A                   D
# 12              NaN            C            E                   D
# 14              NaN            A            A                   B
#
#     foundation_basement_percent exterior_wall  common_wall  roof  \
# 8                            50             D          NaN   NaN
# 9                             0             A          NaN   NaN
# 11                            0             A          NaN   NaN
# 12                            0             A          NaN   NaN
# 14                           50             B          NaN   NaN
#
#    roof_floor_system  floor_finish  interior_finish  interior_finish1  \
# 8                NaN           NaN              NaN               NaN
# 9                NaN           NaN              NaN               NaN
# 11               NaN           NaN              NaN               NaN
# 12               NaN           NaN              NaN               NaN
# 14               NaN           NaN              NaN               NaN
#
#     interior_finish1_percent  interior_finish2  interior_finish2_percent heat  \
# 8                        NaN               NaN                       NaN    A
# 9                        NaN               NaN                       NaN    A
# 11                       NaN               NaN                       NaN    A
# 12                       NaN               NaN                       NaN    A
# 14                       NaN               NaN                       NaN    A
#
#     heat_percent air  air_percent bath  bath_fixtures built_in1_description  \
# 8              0   A            0    C              0         One Fireplace
# 9              0   A            0    A              0                   NaN
# 11             0   A            0    C              0                   NaN
# 12             0   A            0    J              5                   NaN
# 14             0   A            0    J              8         One Fireplace
#
#    built_in2_description built_in3_description built_in4_description  \
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#    built_in5_description city grade  assessed_grade_difference  \
# 8                    NaN  RAL  C+10                        110
# 9                    NaN  RAL  C-10                         90
# 11                   NaN  WEN  C-10                         90
# 12                   NaN  RAL  C+10                        110
# 14                   NaN  NaN     A                        140
#
#     accrued_assessed_condition_pct land_deferred_code  land_deferred_amount  \
# 8                               73                NaN                     0
# 9                               76                NaN                     0
# 11                              54                NaN                     0
# 12                              40                NaN                     0
# 14                              68                NaN                     0
#
#    historic_deferred_code  historic_deferred_amount  recycled_units  \
# 8                     NaN                         0               1
# 9                     NaN                         0               1
# 11                    NaN                         0               1
# 12                    NaN                         0               2
# 14                    NaN                         0               1
#
#    disq_and_qual_flag land_disq_and_qual_flag  type_and_use physical_city  \
# 8                   A                     NaN           1.0       RALEIGH
# 9                   A                     NaN           1.0       RALEIGH
# 11                  I                     NaN           1.0       WENDELL
# 12                  A                     NaN           2.0       RALEIGH
# 14                  A                     NaN           1.0       RALEIGH
#
#     physical_zip_code
# 8             27610.0
# 9             27610.0
# 11            27591.0
# 12            27606.0
# 14            27613.0

# %%
def concatenate_non_empty(*args):
    return ' '.join(filter(lambda x: isinstance(x, str) and x.strip() != '', args))

# %%
house['physical_location'] = house.apply(lambda row: concatenate_non_empty(row['street_number'], row['street_prefix'], row['street_name'], row['street_type'], row['street_suffix'], row['street_misc']), axis=1)

# %%
house['physical_location'].head()
# Out:
# 8            2457 BERTIE DR
# 9        2848 PROVIDENCE RD
# 11         540 MARSHBURN RD
# 12    208 JONES FRANKLIN RD
# 14           8712 W LAKE CT
# Name: physical_location, dtype: object

# %%
house = house.drop(['street_number','street_prefix','street_name','street_type','street_suffix','street_misc'], axis=1)

# %% [markdown]
# #### 2.3.3.2 physical_zip_code

# %%
house['physical_zip_code'].isna().sum()
# Out:
# 245

# %%
missing_zip = house[house['physical_zip_code'].isna()]

# %%
house = house.drop(missing_zip.index)

# %%
house.shape
# Out:
# (329560, 82)

# %%
house = house.drop(house[house['physical_zip_code']==0].index)
house.shape
# Out:
# (329556, 82)

# %% [markdown]
# double check to make sure no 0 and null in physical_zip_code

# %%
house['physical_zip_code'].unique()
# Out:
# array([27610., 27591., 27606., 27613., 27607., 27615., 27608., 27604.,
#        27609., 27513., 27511., 27545., 27526., 27612., 27605., 27529.,
#        27502., 27601., 27587., 27603., 27540., 27614., 27597., 27592.,
#        27571., 27616., 27539., 27562., 27523., 27518., 27617., 27520.,
#        27713., 27560., 27596., 27519., 27522., 27501., 27703.])

# %% [markdown]
# ### 2.3.4 Check Duplicates in real_estate_id

# %% [markdown]
# let's check duplicates in real_estate_id

# %%
duplicates_real_id = house[house.duplicated(subset=['real_estate_id'], keep=False)]
duplicates_real_id.head()
# Out:
#            owner1 owner2               mailing_address1  \
# 301  JC ADAMS INC    NaN  8615 MOUNT PLEASANT CHURCH RD
# 302  JC ADAMS INC    NaN  8615 MOUNT PLEASANT CHURCH RD
# 303  JC ADAMS INC    NaN  8615 MOUNT PLEASANT CHURCH RD
# 304  JC ADAMS INC    NaN  8615 MOUNT PLEASANT CHURCH RD
# 306  JC ADAMS INC    NaN  8615 MOUNT PLEASANT CHURCH RD
#
#                 mailing_address2 mailing_address3  real_estate_id  \
# 301  WILLOW SPRING NC 27592-9765              NaN             351
# 302  WILLOW SPRING NC 27592-9765              NaN             351
# 303  WILLOW SPRING NC 27592-9765              NaN             351
# 304  WILLOW SPRING NC 27592-9765              NaN             351
# 306  WILLOW SPRING NC 27592-9765              NaN             351
#
#      card_number  number_of_cards planning_jurisdiction  township  \
# 301            1                8                    WC        15
# 302            2                8                    WC        15
# 303            3                8                    WC        15
# 304            4                8                    WC        15
# 306            6                8                    WC        15
#
#      fire_district land_sale_price land_sale_date zoning  deeded_acreage  \
# 301           23.0               0            NaN   R-30            57.5
# 302           23.0               0            NaN   R-30            57.5
# 303           23.0               0            NaN   R-30            57.5
# 304           23.0               0            NaN   R-30            57.5
# 306           23.0               0            NaN   R-30            57.5
#
#      total_sale_price total_sale_date assessed_building_value  \
# 301             76500         5/19/05               1,158,651
# 302             76500         5/19/05               1,158,651
# 303             76500         5/19/05               1,158,651
# 304             76500         5/19/05               1,158,651
# 306             76500         5/19/05               1,158,651
#
#     assessed_land_value parcel_identification special_district1  \
# 301           1,064,172   0695.01 47 6513 000               NaN
# 302           1,064,172   0695.01 47 6513 000               NaN
# 303           1,064,172   0695.01 47 6513 000               NaN
# 304           1,064,172   0695.01 47 6513 000               NaN
# 306           1,064,172   0695.01 47 6513 000               NaN
#
#      special_district2  special_district3  billing_class  \
# 301                NaN                NaN              1
# 302                NaN                NaN              1
# 303                NaN                NaN              1
# 304                NaN                NaN              1
# 306                NaN                NaN              1
#
#         property_description land_classification deed_book deed_page  \
# 301  BLACK CREEK LD & OTHERS                   F     11367      0676
# 302  BLACK CREEK LD & OTHERS                   F     11367      0676
# 303  BLACK CREEK LD & OTHERS                   F     11367      0676
# 304  BLACK CREEK LD & OTHERS                   F     11367      0676
# 306  BLACK CREEK LD & OTHERS                   F     11367      0676
#
#     deed_date      vcs property_index  year_built  num_of_rooms  units  \
# 301   5/19/05  EWWC001        EWWC001        1935             0      1
# 302   5/19/05  EWWC001        EWWC001        1940             0      1
# 303   5/19/05  EWWC001        EWWC001        1967             0      2
# 304   5/19/05  EWWC001        EWWC001        1940             0      1
# 306   5/19/05  EWWC001        EWWC001        1953             0      1
#
#      heated_area utilities  street_pavement  topography  year_of_addition  \
# 301         1572         E              NaN         NaN                 0
# 302         1560         E              NaN         NaN                 0
# 303         1568         E              NaN         NaN                 0
# 304         1033         E              NaN         NaN                 0
# 306         1527         E              NaN         NaN                 0
#
#      effective_year  remodeled_year special_write_in story_height  \
# 301            1935               0              NaN            A
# 302            1965               0              NaN            A
# 303            1967               0              NaN            A
# 304            1968               0              NaN            A
# 306            1961               0              NaN            A
#
#     design_style foundation_basement  foundation_basement_percent  \
# 301            A                   D                            0
# 302            A                   D                            0
# 303            E                   D                            0
# 304            A                   D                            0
# 306            A                   D                            0
#
#     exterior_wall  common_wall  roof roof_floor_system  floor_finish  \
# 301             Z          NaN   NaN               NaN           NaN
# 302             Z          NaN   NaN               NaN           NaN
# 303             B          NaN   NaN               NaN           NaN
# 304             Z          NaN   NaN               NaN           NaN
# 306             Z          NaN   NaN               NaN           NaN
#
#      interior_finish  interior_finish1  interior_finish1_percent  \
# 301              NaN               NaN                       NaN
# 302              NaN               NaN                       NaN
# 303              NaN               NaN                       NaN
# 304              NaN               NaN                       NaN
# 306              NaN               NaN                       NaN
#
#      interior_finish2  interior_finish2_percent heat  heat_percent air  \
# 301               NaN                       NaN    A             0   A
# 302               NaN                       NaN    A             0   A
# 303               NaN                       NaN    A             0   A
# 304               NaN                       NaN    A             0   A
# 306               NaN                       NaN    A             0   A
#
#      air_percent bath  bath_fixtures built_in1_description  \
# 301            0    A              0                   NaN
# 302            0    A              0                   NaN
# 303            0    C              0       Multiple Firepl
# 304            0    A              0                   NaN
# 306            0    A              0                   NaN
#
#     built_in2_description built_in3_description built_in4_description  \
# 301                   NaN                   NaN                   NaN
# 302                   NaN                   NaN                   NaN
# 303                   NaN                   NaN                   NaN
# 304                   NaN                   NaN                   NaN
# 306                   NaN                   NaN                   NaN
#
#     built_in5_description city grade  assessed_grade_difference  \
# 301                   NaN  NaN     E                         59
# 302                   NaN  NaN     D                         84
# 303                   NaN  NaN  C-05                         95
# 304                   NaN  NaN     E                         59
# 306                   NaN  NaN  C-05                         95
#
#      accrued_assessed_condition_pct land_deferred_code  land_deferred_amount  \
# 301                              56                  L                889915
# 302                              65                  L                889915
# 303                              53                  L                889915
# 304                              66                  L                889915
# 306                              63                  L                889915
#
#     historic_deferred_code  historic_deferred_amount  recycled_units  \
# 301                    NaN                         0               9
# 302                    NaN                         0               9
# 303                    NaN                         0               9
# 304                    NaN                         0               9
# 306                    NaN                         0               9
#
#     disq_and_qual_flag land_disq_and_qual_flag  type_and_use  physical_city  \
# 301                  E                     NaN           1.0  WILLOW SPRING
# 302                  E                     NaN           1.0  WILLOW SPRING
# 303                  E                     NaN           2.0  WILLOW SPRING
# 304                  E                     NaN           1.0  WILLOW SPRING
# 306                  E                     NaN           1.0  WILLOW SPRING
#
#      physical_zip_code           physical_location
# 301            27592.0  8650 MT PLEASANT CHURCH RD
# 302            27592.0  8620 MT PLEASANT CHURCH RD
# 303            27592.0  8673 MT PLEASANT CHURCH RD
# 304            27592.0        2512 CARLIE ADAMS RD
# 306            27592.0        2692 CARLIE ADAMS RD

# %%
duplicates_real_id.shape
# Out:
# (1476, 82)

# %%
house = house.drop_duplicates('real_estate_id', keep=False)
house.shape
# Out:
# (328080, 82)

# %% [markdown]
# ### 2.3.5 Check Duplicates in physical_location and physical_zip_code

# %% [markdown]
# first, let's check duplicates in physical_location and physical_zip_code

# %%
house[house.duplicated(subset=['physical_location', 'physical_zip_code'], keep=False)].shape
# Out:
# (4, 82)

# %%
duplicate_location_zip = house[house.duplicated(subset=['physical_location', 'physical_zip_code'], keep=False)]

# %%
duplicate_location_zip
# Out:
#                               owner1 owner2   mailing_address1  \
# 26510   FAIRFIELD PLACE CONDOMINIUMS    NaN     318 FURCHES ST
# 55368                JORDAN, JERRY T    NaN    11108 JORDAN RD
# 337790        HANCOCK, REBEKAH BRYAN    NaN  1900 FAIRFIELD DR
# 356113               JORDAN, JERRY T    NaN    11108 JORDAN RD
#
#              mailing_address2 mailing_address3  real_estate_id  card_number  \
# 26510   RALEIGH NC 27607-4016              NaN           29834            1
# 55368   RALEIGH NC 27603-8324              NaN           62398            1
# 337790  RALEIGH NC 27608-2720              NaN          372785            1
# 356113  RALEIGH NC 27603-8324              NaN          414140            1
#
#         number_of_cards planning_jurisdiction  township  fire_district  \
# 26510                 1                    RA         1            NaN
# 55368                 1                    WC        15           23.0
# 337790                1                    RA         1            NaN
# 356113                1                    WC        15           23.0
#
#        land_sale_price land_sale_date zoning  deeded_acreage  \
# 26510                0            NaN   R-10            0.43
# 55368                0            NaN   R-30           50.79
# 337790               0            NaN   R-10            0.00
# 356113               0            NaN   R-30            1.03
#
#         total_sale_price total_sale_date assessed_building_value  \
# 26510             205000         8/31/00                       0
# 55368              78100        12/21/12                  27,376
# 337790            166500        12/11/08                 224,420
# 356113              5800        12/21/12                  66,545
#
#        assessed_land_value parcel_identification special_district1  \
# 26510                    0   1714.05 08 6764 000               NaN
# 55368            1,184,710   1617.03 32 1732 000               NaN
# 337790                   0   1714.05 08 6764 001               NaN
# 356113              48,840   1617.03 12 7317 000               NaN
#
#         special_district2  special_district3  billing_class  \
# 26510                 NaN                NaN              6
# 55368                 NaN                NaN              2
# 337790                NaN                NaN              2
# 356113                NaN                NaN              2
#
#                                      property_description land_classification  \
# 26510                     LO2 MAS CD FAIRFIELD CONDOS BLC                   N
# 55368   LO6 RCMB THOMAS J & WILMA M JORDAN ESTATE BM20...                   F
# 337790  LO2 FAIRFIELD PLACE CONDOMINIUMS BLC BLD2 UN19...                   N
# 356113  LO7 RCMB THOMAS J & WILMA M JORDAN ESTATE BM20...                   F
#
#        deed_book deed_page deed_date      vcs property_index  year_built  \
# 26510      11256      1351    3/9/05  01RA86C        01RA86C        1959
# 55368      15071      1422  12/21/12  15WC900        15WC900        1920
# 337790     13320      1623  12/11/08  01RA86C        01RA86C        1959
# 356113     15071      1422  12/21/12  15WC900        15WC900        1963
#
#         num_of_rooms  units  heated_area utilities  street_pavement  \
# 26510              0      4         3744       ALL              NaN
# 55368              0      1         1274         E              NaN
# 337790             0      1         1008       ALL              NaN
# 356113             0      1          780         E              NaN
#
#         topography  year_of_addition  effective_year  remodeled_year  \
# 26510          NaN                 0            2004               0
# 55368          NaN                 0            1950               0
# 337790         NaN                 0            2004               0
# 356113         NaN                 0            1980               0
#
#        special_write_in story_height design_style foundation_basement  \
# 26510               NaN            C            A                   D
# 55368               NaN            A            A                   C
# 337790              NaN            C            D                   D
# 356113              NaN            A            A                   D
#
#         foundation_basement_percent exterior_wall  common_wall  roof  \
# 26510                             0             A          NaN   NaN
# 55368                             0             A          NaN   NaN
# 337790                            0             A          NaN   NaN
# 356113                            0             A          NaN   NaN
#
#        roof_floor_system  floor_finish  interior_finish  interior_finish1  \
# 26510                NaN           NaN              NaN               NaN
# 55368                NaN           NaN              NaN               NaN
# 337790               NaN           NaN              NaN               NaN
# 356113               NaN           NaN              NaN               NaN
#
#         interior_finish1_percent  interior_finish2  interior_finish2_percent  \
# 26510                        NaN               NaN                       NaN
# 55368                        NaN               NaN                       NaN
# 337790                       NaN               NaN                       NaN
# 356113                       NaN               NaN                       NaN
#
#        heat  heat_percent air  air_percent bath  bath_fixtures  \
# 26510     A             0   A            0    J             35
# 55368     A             0   A            0    A              0
# 337790    A             0   A            0    D              0
# 356113    A             0   A            0    A              0
#
#        built_in1_description built_in2_description built_in3_description  \
# 26510                    NaN                   NaN                   NaN
# 55368                    NaN                   NaN                   NaN
# 337790                   NaN                   NaN                   NaN
# 356113                   NaN                   NaN                   NaN
#
#        built_in4_description built_in5_description city grade  \
# 26510                    NaN                   NaN  RAL  C+10
# 55368                    NaN                   NaN  NaN  D-20
# 337790                   NaN                   NaN  RAL  C+10
# 356113                   NaN                   NaN  NaN     D
#
#         assessed_grade_difference  accrued_assessed_condition_pct  \
# 26510                         110                             126
# 55368                          67                              26
# 337790                        110                             120
# 356113                         84                              66
#
#        land_deferred_code  land_deferred_amount historic_deferred_code  \
# 26510                 NaN                     0                    NaN
# 55368                   L               1062326                    NaN
# 337790                NaN                     0                    NaN
# 356113                  L                   821                    NaN
#
#         historic_deferred_amount  recycled_units disq_and_qual_flag  \
# 26510                          0               0                NaN
# 55368                          0               1                  E
# 337790                         0               1                  A
# 356113                         0               1                  E
#
#        land_disq_and_qual_flag  type_and_use physical_city  physical_zip_code  \
# 26510                      NaN           4.0       RALEIGH            27608.0
# 55368                      NaN           1.0       RALEIGH            27603.0
# 337790                     NaN           1.0       RALEIGH            27608.0
# 356113                     NaN           1.0       RALEIGH            27603.0
#
#         physical_location
# 26510   1900 FAIRFIELD DR
# 55368         0 JORDAN RD
# 337790  1900 FAIRFIELD DR
# 356113        0 JORDAN RD

# %% [markdown]
# check one example

# %%
house = house.drop_duplicates(subset=['physical_location', 'physical_zip_code'], keep=False)
house.shape
# Out:
# (328076, 82)

# %% [markdown]
# ### 2.3.6 Missing Values

# %% [markdown]
# check missing values and percentages

# %%
missing = pd.concat([house.isna().sum().sort_values(ascending=False), 100*house.isna().mean().sort_values(ascending=False)], axis=1)
missing.columns=['count', '%']
missing
# Out:
#                                  count           %
# interior_finish1                328076  100.000000
# special_district2               328076  100.000000
# interior_finish                 328076  100.000000
# floor_finish                    328076  100.000000
# roof_floor_system               328076  100.000000
# roof                            328076  100.000000
# common_wall                     328076  100.000000
# interior_finish2                328076  100.000000
# topography                      328076  100.000000
# street_pavement                 328076  100.000000
# built_in3_description           328076  100.000000
# built_in4_description           328076  100.000000
# built_in5_description           328076  100.000000
# special_district3               328076  100.000000
# special_write_in                328044   99.990246
# built_in2_description           328007   99.978968
# land_deferred_code              327903   99.947268
# historic_deferred_code          327898   99.945744
# special_district1               326060   99.385508
# interior_finish2_percent        324866   99.021568
# interior_finish1_percent        324866   99.021568
# mailing_address3                324705   98.972494
# fire_district                   268363   81.799034
# owner2                          260557   79.419708
# land_disq_and_qual_flag         198118   60.387837
# land_sale_date                  194741   59.358502
# built_in1_description            63772   19.438179
# foundation_basement              63026   19.210793
# city                             55354   16.872310
# utilities                         2161    0.658689
# bath                              1233    0.375828
# heat                              1225    0.373389
# story_height                      1218    0.371255
# exterior_wall                     1218    0.371255
# design_style                      1218    0.371255
# air                               1218    0.371255
# deed_book                          208    0.063400
# disq_and_qual_flag                 189    0.057609
# property_description                19    0.005791
# land_classification                  7    0.002134
# mailing_address2                     1    0.000305
# accrued_assessed_condition_pct       0    0.000000
# air_percent                          0    0.000000
# bath_fixtures                        0    0.000000
# historic_deferred_amount             0    0.000000
# heat_percent                         0    0.000000
# land_deferred_amount                 0    0.000000
# grade                                0    0.000000
# type_and_use                         0    0.000000
# physical_city                        0    0.000000
# assessed_grade_difference            0    0.000000
# physical_zip_code                    0    0.000000
# recycled_units                       0    0.000000
# owner1                               0    0.000000
# foundation_basement_percent          0    0.000000
# remodeled_year                       0    0.000000
# mailing_address1                     0    0.000000
# real_estate_id                       0    0.000000
# card_number                          0    0.000000
# number_of_cards                      0    0.000000
# planning_jurisdiction                0    0.000000
# township                             0    0.000000
# land_sale_price                      0    0.000000
# zoning                               0    0.000000
# deeded_acreage                       0    0.000000
# total_sale_price                     0    0.000000
# total_sale_date                      0    0.000000
# assessed_building_value              0    0.000000
# assessed_land_value                  0    0.000000
# parcel_identification                0    0.000000
# billing_class                        0    0.000000
# deed_page                            0    0.000000
# deed_date                            0    0.000000
# vcs                                  0    0.000000
# property_index                       0    0.000000
# year_built                           0    0.000000
# num_of_rooms                         0    0.000000
# units                                0    0.000000
# heated_area                          0    0.000000
# year_of_addition                     0    0.000000
# effective_year                       0    0.000000
# physical_location                    0    0.000000

# %% [markdown]
# drop columns with missing percentage >95%

# %%
house = house.drop(list(missing[missing['%']>95].index), axis=1)
house.shape
# Out:
# (328076, 60)

# %%
house.columns
# Out:
# Index(['owner1', 'owner2', 'mailing_address1', 'mailing_address2',
#        'real_estate_id', 'card_number', 'number_of_cards',
#        'planning_jurisdiction', 'township', 'fire_district', 'land_sale_price',
#        'land_sale_date', 'zoning', 'deeded_acreage', 'total_sale_price',
#        'total_sale_date', 'assessed_building_value', 'assessed_land_value',
#        'parcel_identification', 'billing_class', 'property_description',
#        'land_classification', 'deed_book', 'deed_page', 'deed_date', 'vcs',
#        'property_index', 'year_built', 'num_of_rooms', 'units', 'heated_area',
#        'utilities', 'year_of_addition', 'effective_year', 'remodeled_year',
#        'story_height', 'design_style', 'foundation_basement',
#        'foundation_basement_percent', 'exterior_wall', 'heat', 'heat_percent',
#        'air', 'air_percent', 'bath', 'bath_fixtures', 'built_in1_description',
#        'city', 'grade', 'assessed_grade_difference',
#        'accrued_assessed_condition_pct', 'land_deferred_amount',
#        'historic_deferred_amount', 'recycled_units', 'disq_and_qual_flag',
#        'land_disq_and_qual_flag', 'type_and_use', 'physical_city',
#        'physical_zip_code', 'physical_location'],
#       dtype='object')

# %% [markdown]
# ### 2.3.7 Clean Price Variables

# %%
house['assessed_building_value'].unique(), house['assessed_land_value'].unique(), house['land_sale_price'].unique()
# Out:
# (array(['134,321', '114,933', '118,723', ..., '105,673', '400,775',
#         '404,098'], dtype=object),
#  array(['115,000', '45,000', '32,000', ..., '24,840', '49,140', '102,248'],
#        dtype=object),
#  array(['0', '30,500', '450,000', ..., '66,921', '93,700', '2,323,000'],
#        dtype=object))

# %% [markdown]
# these three variables have comma in them, delete it and change to numeric.

# %%
# remove , in values
house['assessed_building_value'] = house['assessed_building_value'].str.replace(',','')
house['assessed_land_value'] = house['assessed_land_value'].str.replace(',','')
house['land_sale_price'] = house['land_sale_price'].str.replace(',','')
# change to numeric
house['assessed_building_value'] = pd.to_numeric(house['assessed_building_value'], errors = 'coerce')
house['assessed_land_value'] = pd.to_numeric(house['assessed_land_value'], errors = 'coerce')
house['land_sale_price'] = pd.to_numeric(house['land_sale_price'], errors = 'coerce')

# %% [markdown]
# **drop land sale information since more than 50% house land are sold with house together, so NO land sale price**

# %%
house = house.drop(['land_sale_price', 'land_sale_date'], axis=1)
house.shape
# Out:
# (328076, 58)

# %% [markdown]
# **drop all assessed information, since these information may not be available before transaction**

# %%
house = house.drop(['assessed_building_value', 'assessed_land_value', 'assessed_grade_difference',
       'accrued_assessed_condition_pct'], axis=1)
house.shape
# Out:
# (328076, 54)

# %% [markdown]
# **check deed_book and deed_page, deek_book and deed_page, deed date are information after transaction, not useful for price prediction before transaction, so drop them directly.**

# %%
house = house.drop(['deed_book', 'deed_page', 'deed_date'], axis=1)
house.shape
# Out:
# (328076, 51)

# %% [markdown]
# ### 2.3.8 Change Date to Datetime

# %% [markdown]
# check the format first

# %%
 house['total_sale_date'].unique()
# Out:
# array(['1/1/74', '5/18/83', '9/16/04', ..., '11/3/07', '6/25/05',
#        '2/21/22'], dtype=object)

# %% [markdown]
# change to datetime and extract year and month

# %%
house['total_sale_date'] = pd.to_datetime(house['total_sale_date'])

# %%
house['total_sale_year'] = house['total_sale_date'].dt.year
house['total_sale_month'] = house['total_sale_date'].dt.month
house = house.drop(['total_sale_date'], axis=1)

# %%
house.shape
# Out:
# (328076, 52)

# %% [markdown]
# ### 2.3.9 Check All Datetime Variables

# %%
year_built = house['year_built'].unique()
year_of_addition = house['year_of_addition'].unique()
effective_year = house['effective_year'].unique()
remodeled_year = house['remodeled_year'].unique()
total_sale_year = house['total_sale_year'].unique()

# %%
year_built.sort()
year_of_addition.sort()
effective_year.sort()
remodeled_year.sort()
total_sale_year.sort()

# %%
year_built, year_of_addition, effective_year, remodeled_year, total_sale_year
# Out:
# (array([1790, 1800, 1806, 1814, 1820, 1833, 1835, 1840, 1841, 1850, 1852,
#         1854, 1855, 1856, 1860, 1865, 1867, 1868, 1870, 1871, 1872, 1875,
#         1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886,
#         1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1898,
#         1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909,
#         1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920,
#         1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#         1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#         1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#         1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#         1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#         1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#         1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#         1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#         2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#         2020, 2021, 2022, 2023, 2024], dtype=int64),
#  array([   0, 1979, 1980, 1982, 1984, 1985, 1987, 1988, 1990, 1991, 1993,
#         1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#         2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#         2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2077, 2102,
#         2149, 2202], dtype=int64),
#  array([1840, 1850, 1885, 1890, 1891, 1900, 1901, 1904, 1905, 1906, 1907,
#         1908, 1909, 1910, 1911, 1914, 1915, 1916, 1917, 1918, 1919, 1920,
#         1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#         1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#         1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#         1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#         1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#         1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#         1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#         1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#         2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#         2020, 2021, 2022, 2023, 2024, 2050, 2208, 2209, 2999], dtype=int64),
#  array([   0, 1985, 1990, 1995, 1998, 2000, 2002, 2003, 2004, 2005, 2006,
#         2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#         2018, 2019, 2020, 2021, 2022, 2023, 2024, 2209], dtype=int64),
#  array([1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#         1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#         1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#         2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#         2018, 2019, 2020, 2021, 2022, 2023, 2056, 2058, 2061, 2062, 2063,
#         2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073]))

# %% [markdown]
# change all 0 and invalid date in year_built, year_of_addition, effective_year, remodeled_year, land_sale_year, total_sale_year and deed_year to nan.

# %%
house['year_built'] = house['year_built'].replace([0, 2024], np.nan)
house['year_of_addition'] = house['year_of_addition'].replace([0, 2024, 2077, 2102, 2149, 2202], np.nan)
house['effective_year'] = house['effective_year'].replace([0, 2024, 2050, 2208, 2209, 2999], np.nan)
house['remodeled_year'] = house['remodeled_year'].replace([0, 2024, 2209], np.nan)


house['total_sale_year'] = house['total_sale_year'].replace([0, 2056., 2058., 2061., 2062.,
                                                             2063., 2064., 2065., 2066., 2067.,
                                                             2068., 2069., 2070.,2071., 2072.], np.nan)

# %%
house['year_built'] = pd.to_datetime(house['year_built'], format='%Y').dt.year
house['effective_year'] = pd.to_datetime(house['effective_year'], format='%Y').dt.year
house['year_of_addition'] = pd.to_datetime(house['year_of_addition'], format='%Y').dt.year
house['remodeled_year'] = pd.to_datetime(house['remodeled_year'], format='%Y').dt.year

# %% [markdown]
# ### 2.3.10 Check Variables

# %%
house.columns
# Out:
# Index(['owner1', 'owner2', 'mailing_address1', 'mailing_address2',
#        'real_estate_id', 'card_number', 'number_of_cards',
#        'planning_jurisdiction', 'township', 'fire_district', 'zoning',
#        'deeded_acreage', 'total_sale_price', 'parcel_identification',
#        'billing_class', 'property_description', 'land_classification', 'vcs',
#        'property_index', 'year_built', 'num_of_rooms', 'units', 'heated_area',
#        'utilities', 'year_of_addition', 'effective_year', 'remodeled_year',
#        'story_height', 'design_style', 'foundation_basement',
#        'foundation_basement_percent', 'exterior_wall', 'heat', 'heat_percent',
#        'air', 'air_percent', 'bath', 'bath_fixtures', 'built_in1_description',
#        'city', 'grade', 'land_deferred_amount', 'historic_deferred_amount',
#        'recycled_units', 'disq_and_qual_flag', 'land_disq_and_qual_flag',
#        'type_and_use', 'physical_city', 'physical_zip_code',
#        'physical_location', 'total_sale_year', 'total_sale_month'],
#       dtype='object')

# %%
house.dtypes
# Out:
# owner1                          object
# owner2                          object
# mailing_address1                object
# mailing_address2                object
# real_estate_id                   int64
# card_number                      int64
# number_of_cards                  int64
# planning_jurisdiction           object
# township                         int64
# fire_district                  float64
# zoning                          object
# deeded_acreage                 float64
# total_sale_price                 int64
# parcel_identification           object
# billing_class                    int64
# property_description            object
# land_classification             object
# vcs                             object
# property_index                  object
# year_built                     float64
# num_of_rooms                     int64
# units                            int64
# heated_area                      int64
# utilities                       object
# year_of_addition               float64
# effective_year                 float64
# remodeled_year                 float64
# story_height                    object
# design_style                    object
# foundation_basement             object
# foundation_basement_percent      int64
# exterior_wall                   object
# heat                            object
# heat_percent                     int64
# air                             object
# air_percent                      int64
# bath                            object
# bath_fixtures                    int64
# built_in1_description           object
# city                            object
# grade                           object
# land_deferred_amount             int64
# historic_deferred_amount         int64
# recycled_units                   int64
# disq_and_qual_flag              object
# land_disq_and_qual_flag         object
# type_and_use                   float64
# physical_city                   object
# physical_zip_code              float64
# physical_location               object
# total_sale_year                float64
# total_sale_month                 int32
# dtype: object

# %%
house['township'].unique(), house['fire_district'].unique(), house['billing_class'].unique(), house['type_and_use'].unique()
# Out:
# (array([ 1, 16, 10,  8, 13,  4,  7, 17, 12, 20, 11, 19, 15,  6, 18,  2,  9,
#          3, 14,  5], dtype=int64),
#  array([nan, 23., 24., 26.]),
#  array([2, 1, 3, 5, 6, 4], dtype=int64),
#  array([1., 2., 3., 4.]))

# %% [markdown]
# township is the township of the house located at, in this dataset, it use numbers 1-20 to represent 20 townships<br>
#
# fire_district is thefire districtp of the house located at, in this dataset, it use numbers23.0, 24.0, 26.0, but cannot find these numbers from the support documents, maybe there are some input error, drop this column.
#
# billing_class use number 1-6 to represent corporation, individuals, exempt, public service, life estate and HOA.<br>
#
# type_and_use is the use of the house, it also use numbers to represent the use. for example, 1 means 1 family, 8 means townhouse etc.
#
# deed_book is the deed book of the house, it should be continuous variable
#
# deed_page is the deed page of the house, it should be continuous variable

# %%
house['township'] = house['township'].map({1:'RALEIGH', 2:"BARTON'S CREEK", 3:"BUCKHORN", 4:"CARY",
                                          5:"CEDAR FORK", 6: "HOLLY SPRING", 7:"HOUSE CREEK", 8:"LEESVILLE", 9:"LITTLE RIVER", 10:"MARK'S CREEK",
                                          11:"MEREDITH", 12:"MIDDLE CREEK", 13:"NEUSE", 14:"NEW LIGHT", 15:"PANTHER BRANCH",
                                          16:"ST MARY'S", 17:"ST MATTHEW'S", 18:"SWIFT CREEK", 19:"WAKE FOREST", 20:"WHITE OAK"})

house = house.drop('fire_district', axis=1)

house['billing_class'] = house['billing_class'].map({1:"CORPORATION", 2:"INDIVIDUALS", 3:"EXEMPT", 4:"PUBLIC SERVICE",
                                                     5:"LIFE ESTATE", 6:"HOA"})

house['type_and_use'] = house['type_and_use'].map({1.0:"ONE FAMILY", 2.0:"TWO FAMILY",   3.0:"THREE FAMILY",   4.0:"FOUR FAMILY",
                                            })

# %% [markdown]
# check foundation_basement and foundation_basement_percent. foundation_basement = A means full basement, B means %basement, C and D means no basement.

# %%
house['foundation_basement'].value_counts(dropna=False)
# Out:
# foundation_basement
# D      219364
# NaN     63026
# A       29390
# B       16049
# C         244
# E           2
# F           1
# Name: count, dtype: int64

# %%
house.loc[house['foundation_basement_percent']!=0,'foundation_basement']='B'
house.loc[house['foundation_basement']=='A','foundation_basement_percent']=100
house['foundation_basement'] = house['foundation_basement'].fillna('C')
house['foundation_basement'] = house['foundation_basement'].str.replace('D', 'C')
house['foundation_basement'] = house['foundation_basement'].str.replace('E', 'C')
house['foundation_basement'] = house['foundation_basement'].str.replace('F', 'C')

# %% [markdown]
# check story_height

# %%
house['story_height'].value_counts().sort_index()
# Out:
# story_height
# A    100971
# B     23445
# C    153643
# D         6
# E      1375
# I     21286
# J      4813
# K      7593
# L     13721
# M         3
# N         1
# O         1
# Name: count, dtype: int64

# %%
house = house.drop(house[house['story_height']=='O'].index)   # story_height='O' CANNOT found in code description
house['story_height'] = house['story_height'].map({'A':1,'B':1.5,'C':2,'D':2.5,'E':3, 'F':3.5, 'G':4, 'H':5,
                                                   'I':1.75,'J':1.4,'K':1.63,'L':1.88,'M':2.4,'N':2.63})

# %% [markdown]
# check bath

# %%
house['bath'].value_counts().sort_index()
# Out:
# bath
# A     11591
# B     10746
# C     59104
# D    134122
# E     32920
# F     62092
# H        25
# I         7
# J     16235
# Name: count, dtype: int64

# %%
house['bath'] = house['bath'].map({'A':1,'B':1.5,'C':2,'D':2.5,'E':3,'F':3.5, 'G': 1,'H':0,'I':2.5,'J':2.5})

# %% [markdown]
# check built_in1_description

# %% [markdown]
# ### 2.3.11 Drop Useless Variables

# %%
house['num_of_rooms'].unique(), house['card_number'].unique(), house['number_of_cards'].unique()
# Out:
# (array([0], dtype=int64),
#  array([1, 2, 6, 3, 4, 5], dtype=int64),
#  array([1, 2, 3, 5, 7, 4, 9], dtype=int64))

# %% [markdown]
# drop the num_of_rooms column because it only has 0 <br>
# card_number is house number in the compounds, number_of_cards means how many house in that compund<br>
# drop the card_number column and number_of_cards column because we have drop duplicates in real_estate_id. these are for house with same id.<br>
# drop city because already have physical city.

# %%
house.head(2)
# Out:
#                            owner1 owner2    mailing_address1  \
# 8  MICKENS, ROBERT EARL & ANNIE M    NaN      2457 BERTIE DR
# 9  COREY, JAMES CURTIS & REGINA B    NaN  2848 PROVIDENCE RD
#
#         mailing_address2  real_estate_id  card_number  number_of_cards  \
# 8  RALEIGH NC 27610-1730              19            1                1
# 9  RALEIGH NC 27610-5210              20            1                1
#
#   planning_jurisdiction   township zoning  deeded_acreage  total_sale_price  \
# 8                    RA    RALEIGH    R-4            0.21             34500
# 9                    RA  ST MARY'S    R-4            0.46             35500
#
#   parcel_identification billing_class          property_description  \
# 8   1714.20 81 7084 000   INDIVIDUALS     LO22 LONGVIEW GARDENS BLR
# 9   1722.11 65 9239 000   INDIVIDUALS  LO18 GREEN VALLEY BM1959-315
#
#   land_classification      vcs property_index  year_built  num_of_rooms  \
# 8                   R  01RA512        01RA512      1964.0             0
# 9                   R  16RA030        16RA030      1970.0             0
#
#    units  heated_area utilities  year_of_addition  effective_year  \
# 8      1         1828       ALL               NaN          1980.0
# 9      1         1240         E               NaN          1985.0
#
#    remodeled_year  story_height design_style foundation_basement  \
# 8             NaN           1.0            I                   B
# 9             NaN           1.0            A                   C
#
#    foundation_basement_percent exterior_wall heat  heat_percent air  \
# 8                           50             D    A             0   A
# 9                            0             A    A             0   A
#
#    air_percent  bath  bath_fixtures built_in1_description city grade  \
# 8            0   2.0              0         One Fireplace  RAL  C+10
# 9            0   1.0              0                   NaN  RAL  C-10
#
#    land_deferred_amount  historic_deferred_amount  recycled_units  \
# 8                     0                         0               1
# 9                     0                         0               1
#
#   disq_and_qual_flag land_disq_and_qual_flag type_and_use physical_city  \
# 8                  A                     NaN   ONE FAMILY       RALEIGH
# 9                  A                     NaN   ONE FAMILY       RALEIGH
#
#    physical_zip_code   physical_location  total_sale_year  total_sale_month
# 8            27610.0      2457 BERTIE DR           1974.0                 1
# 9            27610.0  2848 PROVIDENCE RD           1983.0                 5

# %%
house = house.drop(["num_of_rooms", 'card_number', 'number_of_cards', 'city'], axis=1)
house.shape
# Out:
# (328075, 47)

# %%
house.head(2)
# Out:
#                            owner1 owner2    mailing_address1  \
# 8  MICKENS, ROBERT EARL & ANNIE M    NaN      2457 BERTIE DR
# 9  COREY, JAMES CURTIS & REGINA B    NaN  2848 PROVIDENCE RD
#
#         mailing_address2  real_estate_id planning_jurisdiction   township  \
# 8  RALEIGH NC 27610-1730              19                    RA    RALEIGH
# 9  RALEIGH NC 27610-5210              20                    RA  ST MARY'S
#
#   zoning  deeded_acreage  total_sale_price parcel_identification  \
# 8    R-4            0.21             34500   1714.20 81 7084 000
# 9    R-4            0.46             35500   1722.11 65 9239 000
#
#   billing_class          property_description land_classification      vcs  \
# 8   INDIVIDUALS     LO22 LONGVIEW GARDENS BLR                   R  01RA512
# 9   INDIVIDUALS  LO18 GREEN VALLEY BM1959-315                   R  16RA030
#
#   property_index  year_built  units  heated_area utilities  year_of_addition  \
# 8        01RA512      1964.0      1         1828       ALL               NaN
# 9        16RA030      1970.0      1         1240         E               NaN
#
#    effective_year  remodeled_year  story_height design_style  \
# 8          1980.0             NaN           1.0            I
# 9          1985.0             NaN           1.0            A
#
#   foundation_basement  foundation_basement_percent exterior_wall heat  \
# 8                   B                           50             D    A
# 9                   C                            0             A    A
#
#    heat_percent air  air_percent  bath  bath_fixtures built_in1_description  \
# 8             0   A            0   2.0              0         One Fireplace
# 9             0   A            0   1.0              0                   NaN
#
#   grade  land_deferred_amount  historic_deferred_amount  recycled_units  \
# 8  C+10                     0                         0               1
# 9  C-10                     0                         0               1
#
#   disq_and_qual_flag land_disq_and_qual_flag type_and_use physical_city  \
# 8                  A                     NaN   ONE FAMILY       RALEIGH
# 9                  A                     NaN   ONE FAMILY       RALEIGH
#
#    physical_zip_code   physical_location  total_sale_year  total_sale_month
# 8            27610.0      2457 BERTIE DR           1974.0                 1
# 9            27610.0  2848 PROVIDENCE RD           1983.0                 5

# %%
zero_value_columns = ['units', 'foundation_basement_percent', 
                      'heat_percent', 'air_percent', 'bath_fixtures', 
                      'land_deferred_amount', 'historic_deferred_amount', 'recycled_units']

for column in zero_value_columns:
    print(f"In column {column}. there are {house[house[column]==0].shape[0]/house.shape[0]*100}% have value 0")
# Out:
# In column units. there are 0.48342604587365695% have value 0
# In column foundation_basement_percent. there are 86.1488988798293% have value 0
# In column heat_percent. there are 99.99329421626153% have value 0
# In column air_percent. there are 99.9737864817496% have value 0
# In column bath_fixtures. there are 93.22746323249257% have value 0
# In column land_deferred_amount. there are 99.94726815514746% have value 0
# In column historic_deferred_amount. there are 99.92989407909776% have value 0
# In column recycled_units. there are 0.528537681932485% have value 0

# %%
house = house.drop(['foundation_basement_percent', 'heat_percent', 'air_percent', 
                    'bath_fixtures', 'land_deferred_amount', 'historic_deferred_amount'], axis=1)
house.shape
# Out:
# (328075, 41)

# %% [markdown]
# ## 2.4 Data Manipulation
# ### 2.4.1 Merge with Longitude and Latitude of Zipcode

# %%
house['physical_zip_code'].unique()
# Out:
# array([27610., 27591., 27606., 27613., 27607., 27615., 27608., 27604.,
#        27609., 27513., 27511., 27545., 27526., 27612., 27605., 27529.,
#        27502., 27601., 27587., 27603., 27540., 27614., 27597., 27592.,
#        27571., 27616., 27539., 27562., 27523., 27518., 27617., 27520.,
#        27713., 27560., 27596., 27519., 27522., 27501., 27703.])

# %%
house['physical_city'].unique()
# Out:
# array(['RALEIGH', 'WENDELL', 'CARY', 'KNIGHTDALE', 'FUQUAY VARINA',
#        'GARNER', 'APEX', 'WAKE FOREST', 'HOLLY SPRINGS', 'ZEBULON',
#        'WILLOW SPRING', 'ROLESVILLE', 'NEW HILL', 'CLAYTON', 'DURHAM',
#        'MORRISVILLE', 'YOUNGSVILLE', 'CREEDMOOR', 'ANGIER'], dtype=object)

# %%
zipcode_lat_long = pd.read_csv('../Data/zipcode_long_lat.csv', index_col=0)
zipcode_lat_long = zipcode_lat_long.reset_index()
zipcode_lat_long.head()
# Out:
#    zipcode  latitude  longitude
# 0    27615   35.8915   -78.6341
# 1    27605   35.7917   -78.6583
# 2    27592   35.5613   -78.6735
# 3    27518   35.7313   -78.7721
# 4    27617   35.9071   -78.7800

# %%
house = house.merge(zipcode_lat_long, left_on='physical_zip_code', right_on='zipcode')
house = house.drop('zipcode', axis=1)
house.shape
# Out:
# (328075, 43)

# %% [markdown]
# ### 2.4.2 Calculate City Longitude and Latitude

# %%
city_lat_long = house.groupby('physical_city')[['latitude', 'longitude']].mean()
city_lat_long = city_lat_long.reset_index()
city_lat_long = city_lat_long.rename({'latitude':'latitude_city', 'longitude':'longitude_city'}, axis=1)
city_lat_long.head()
# Out:
#   physical_city  latitude_city  longitude_city
# 0        ANGIER      35.495100      -78.710000
# 1          APEX      35.723154      -78.856858
# 2          CARY      35.786214      -78.824309
# 3       CLAYTON      35.619600      -78.476400
# 4     CREEDMOOR      36.110400      -78.689500

# %% [markdown]
# ### 2.4.3 Calculate Distance to Nearest City

# %%
dic = {}
for zipcode, lat_zip, long_zip in zip(list(zipcode_lat_long['zipcode']), list(zipcode_lat_long['latitude']), list(zipcode_lat_long['longitude'])):
  res = []
  for lat_city, long_city in zip(list(city_lat_long['latitude_city']), list(city_lat_long['longitude_city'])):
    distance = np.arccos((np.sin(np.radians(lat_zip)) * np.sin(np.radians(lat_city))) + (np.cos(np.radians(lat_zip)) * np.cos(np.radians(lat_city))) * (np.cos(np.radians(long_city) - np.radians(long_zip))))*6371
    res.append(distance)
    dic[zipcode] = min(res)

# %%
dic
# Out:
# {27615: 6.9365033701659,
#  27605: 4.630673552000703,
#  27592: 0.00013425878593145295,
#  27518: 7.7044420120366,
#  27617: 7.906051396556633,
#  27608: 2.4615727960487486,
#  27529: 0.0,
#  27571: 0.0,
#  27522: 0.0,
#  27604: 4.7656835685320615,
#  27609: 2.0720067571049863,
#  27603: 7.490937681225698,
#  27616: 8.802493277047839,
#  27713: 9.643572708815533,
#  27601: 6.008603980830653,
#  27513: 2.2682002046296463,
#  27502: 1.5805612691924815,
#  27539: 6.83947043350296,
#  27519: 5.557205096354483,
#  27610: 8.566331161520948,
#  27511: 4.357910344031159,
#  27587: 0.0,
#  27560: 6.6624255414908955,
#  27596: 0.0,
#  27591: 0.0,
#  27545: 0.0,
#  27540: 0.0,
#  27562: 0.0,
#  27501: 0.0,
#  27606: 10.388040111930382,
#  27526: 9.493529796600342e-05,
#  27614: 7.049722946334923,
#  27520: 0.0,
#  27703: 0.2051383306108425,
#  27613: 10.688499714461905,
#  27612: 5.738716424605332,
#  27597: 0.0,
#  27523: 7.550341605719256,
#  27607: 6.659336227852699}

# %% [markdown]
# if we use this method, there will have lots of house have 0 distance to nearest city downtown, doesn't make any sense. let's try to find downtown longitude and latitude for each city which is not too much.

# %% [markdown]
# ### 2.4.4 City Downtown's Longitude and Latitude

# %%
city_lat_long.loc[city_lat_long['physical_city']=='ANGIER', 'latitude_city'] = 35.507238158725464
city_lat_long.loc[city_lat_long['physical_city']=='ANGIER', 'longitude_city'] = -78.74090509660199
city_lat_long.loc[city_lat_long['physical_city']=='APEX', 'latitude_city'] = 35.73190359365108
city_lat_long.loc[city_lat_long['physical_city']=='APEX', 'longitude_city'] = -78.85091175391851
city_lat_long.loc[city_lat_long['physical_city']=='CARY', 'latitude_city'] = 35.78784113228582
city_lat_long.loc[city_lat_long['physical_city']=='CARY', 'longitude_city'] = -78.78101042950871
city_lat_long.loc[city_lat_long['physical_city']=='CLAYTON', 'latitude_city'] = 35.651977102648424
city_lat_long.loc[city_lat_long['physical_city']=='CLAYTON', 'longitude_city'] = -78.45822881758771
city_lat_long.loc[city_lat_long['physical_city']=='CREEDMOOR', 'latitude_city'] = 36.1190601320684
city_lat_long.loc[city_lat_long['physical_city']=='CREEDMOOR', 'longitude_city'] = -78.68749145444488
city_lat_long.loc[city_lat_long['physical_city']=='DURHAM', 'latitude_city'] = 35.99656935465194
city_lat_long.loc[city_lat_long['physical_city']=='DURHAM', 'longitude_city'] = -78.90159465555615
city_lat_long.loc[city_lat_long['physical_city']=='FUQUAY VARINA', 'latitude_city'] = 35.618744215230386
city_lat_long.loc[city_lat_long['physical_city']=='FUQUAY VARINA', 'longitude_city'] = -78.78493543312048
city_lat_long.loc[city_lat_long['physical_city']=='GARNER', 'latitude_city'] = 35.706785345955616,
city_lat_long.loc[city_lat_long['physical_city']=='GARNER', 'longitude_city'] = -78.62040028970598
city_lat_long.loc[city_lat_long['physical_city']=='HOLLY SPRINGS', 'latitude_city'] = 35.65485549336737
city_lat_long.loc[city_lat_long['physical_city']=='HOLLY SPRINGS', 'longitude_city'] = -78.83427524907096
city_lat_long.loc[city_lat_long['physical_city']=='KNIGHTDALE', 'latitude_city'] = 35.797608642393335
city_lat_long.loc[city_lat_long['physical_city']=='KNIGHTDALE', 'longitude_city'] = -78.49642108275224
city_lat_long.loc[city_lat_long['physical_city']=='MORRISVILLE', 'latitude_city'] = 35.585649739678146
city_lat_long.loc[city_lat_long['physical_city']=='MORRISVILLE', 'longitude_city'] = -80.80923359588809
city_lat_long.loc[city_lat_long['physical_city']=='NEW HILL', 'latitude_city'] = 35.68372912335758
city_lat_long.loc[city_lat_long['physical_city']=='NEW HILL', 'longitude_city'] = -78.93573654813744
city_lat_long.loc[city_lat_long['physical_city']=='RALEIGH', 'latitude_city'] = 35.77686974485129
city_lat_long.loc[city_lat_long['physical_city']=='RALEIGH', 'longitude_city'] = -78.63958274423874
city_lat_long.loc[city_lat_long['physical_city']=='ROLESVILLE', 'latitude_city'] = 35.9169779931441
city_lat_long.loc[city_lat_long['physical_city']=='ROLESVILLE', 'longitude_city'] = -78.46601703986266
city_lat_long.loc[city_lat_long['physical_city']=='WAKE FOREST', 'latitude_city'] = 35.98018604933968
city_lat_long.loc[city_lat_long['physical_city']=='WAKE FOREST', 'longitude_city'] = -78.50999036543806
city_lat_long.loc[city_lat_long['physical_city']=='WENDELL', 'latitude_city'] = 35.78090031527201
city_lat_long.loc[city_lat_long['physical_city']=='WENDELL', 'longitude_city'] = -78.37047303905644
city_lat_long.loc[city_lat_long['physical_city']=='YOUNGSVILLE', 'latitude_city'] = 36.02495161443923
city_lat_long.loc[city_lat_long['physical_city']=='YOUNGSVILLE', 'longitude_city'] = -78.47689807500163
city_lat_long.loc[city_lat_long['physical_city']=='WILLOW SPRING', 'latitude_city'] = 35.591680352150085
city_lat_long.loc[city_lat_long['physical_city']=='WILLOW SPRING', 'longitude_city'] = -78.73024272090669
city_lat_long.loc[city_lat_long['physical_city']=='ZEBULON', 'latitude_city'] = 35.82166315772092
city_lat_long.loc[city_lat_long['physical_city']=='ZEBULON', 'longitude_city'] = -78.3127742359601

# %%
dic_distance = {}
dic_city = {}
lst = []
for zipcode, lat_zip, long_zip in zip(list(zipcode_lat_long['zipcode']), list(zipcode_lat_long['latitude']), list(zipcode_lat_long['longitude'])):
  res = []
  for lat_city, long_city in zip(list(city_lat_long['latitude_city']), list(city_lat_long['longitude_city'])):
    distance = np.arccos((np.sin(np.radians(lat_zip)) * np.sin(np.radians(lat_city))) + (np.cos(np.radians(lat_zip)) * np.cos(np.radians(lat_city))) * (np.cos(np.radians(long_city) - np.radians(long_zip))))*6371
    res.append(distance)
    dic_distance[zipcode] = min(res)
    dic_city[zipcode] = list(city_lat_long['physical_city'])[np.argmin(res)]

# %%
dic_distance
# Out:
# {27615: 12.755881901659262,
#  27605: 2.3600766867649163,
#  27592: 6.143848812563611,
#  27518: 6.338287607120317,
#  27617: 13.26129377131298,
#  27608: 3.5754037114956483,
#  27529: 5.4295644602954525,
#  27571: 0.47519614712992203,
#  27522: 0.9797191486898211,
#  27604: 6.946425991987146,
#  27609: 7.859930529086905,
#  27603: 3.7781847932285317,
#  27616: 9.041617933161586,
#  27713: 9.752088715496777,
#  27601: 0.4497414631505077,
#  27513: 2.2609197528139897,
#  27502: 1.9550451376995501,
#  27539: 5.445565910384288,
#  27519: 8.75332013724478,
#  27610: 6.2129903291979875,
#  27511: 2.285813565406272,
#  27587: 1.9487872820030296,
#  27560: 8.050094272689105,
#  27596: 2.2502105700132717,
#  27591: 1.4015756273587365,
#  27545: 1.3321207608612617,
#  27540: 1.8582819397537709,
#  27562: 4.4524712167974645,
#  27501: 3.106218081452512,
#  27606: 6.835158730469106,
#  27526: 5.575555657189741,
#  27614: 8.997808766651822,
#  27520: 3.957011987715249,
#  27703: 7.177401546665531,
#  27613: 14.37523007401981,
#  27612: 9.449742085897007,
#  27597: 2.002411239678604,
#  27523: 7.396985296037231,
#  27607: 6.265997947282161}

# %%
dic_city
# Out:
# {27615: 'RALEIGH',
#  27605: 'RALEIGH',
#  27592: 'WILLOW SPRING',
#  27518: 'CARY',
#  27617: 'CARY',
#  27608: 'RALEIGH',
#  27529: 'GARNER',
#  27571: 'ROLESVILLE',
#  27522: 'CREEDMOOR',
#  27604: 'RALEIGH',
#  27609: 'RALEIGH',
#  27603: 'GARNER',
#  27616: 'KNIGHTDALE',
#  27713: 'DURHAM',
#  27601: 'RALEIGH',
#  27513: 'CARY',
#  27502: 'APEX',
#  27539: 'HOLLY SPRINGS',
#  27519: 'APEX',
#  27610: 'RALEIGH',
#  27511: 'CARY',
#  27587: 'WAKE FOREST',
#  27560: 'CARY',
#  27596: 'YOUNGSVILLE',
#  27591: 'WENDELL',
#  27545: 'KNIGHTDALE',
#  27540: 'HOLLY SPRINGS',
#  27562: 'NEW HILL',
#  27501: 'ANGIER',
#  27606: 'CARY',
#  27526: 'FUQUAY VARINA',
#  27614: 'WAKE FOREST',
#  27520: 'CLAYTON',
#  27703: 'DURHAM',
#  27613: 'CARY',
#  27612: 'RALEIGH',
#  27597: 'ZEBULON',
#  27523: 'APEX',
#  27607: 'RALEIGH'}

# %% [markdown]
# ### 2.4.5 Dataframe with Zipcode and Distance

# %%
zipcode_distance_city = pd.DataFrame([dic_distance, dic_city]).T.reset_index()
zipcode_distance_city.columns = ['zipcode', 'distance_nearest_city', 'nearest_city']
zipcode_distance_city['distance_nearest_city'] = pd.to_numeric(zipcode_distance_city['distance_nearest_city'])
zipcode_distance_city.head()
# Out:
#    zipcode  distance_nearest_city   nearest_city
# 0    27615              12.755882        RALEIGH
# 1    27605               2.360077        RALEIGH
# 2    27592               6.143849  WILLOW SPRING
# 3    27518               6.338288           CARY
# 4    27617              13.261294           CARY

# %%
house = house.merge(zipcode_distance_city, left_on='physical_zip_code', right_on='zipcode')
house.head()
# Out:
#                            owner1                      owner2  \
# 0  MICKENS, ROBERT EARL & ANNIE M                         NaN
# 1  COREY, JAMES CURTIS & REGINA B                         NaN
# 2             ADDISON, KIMBERLY D                         NaN
# 3                 POWELL, JAMES A                         NaN
# 4            CAMPUS HOLDINGS, LLC  QUEWHIFFLE PROPERTIES, LLC
#
#          mailing_address1       mailing_address2  real_estate_id  \
# 0          2457 BERTIE DR  RALEIGH NC 27610-1730              19
# 1      2848 PROVIDENCE RD  RALEIGH NC 27610-5210              20
# 2  4212 KNIGHTSBRIDGE WAY  RALEIGH NC 27604-8440              69
# 3         2807 CROYDON ST  RALEIGH NC 27610-3651              72
# 4            PO BOX 12603  RALEIGH NC 27605-2603              79
#
#   planning_jurisdiction   township zoning  deeded_acreage  total_sale_price  \
# 0                    RA    RALEIGH    R-4            0.21             34500
# 1                    RA  ST MARY'S    R-4            0.46             35500
# 2                    RA  ST MARY'S    R-4            0.36             81000
# 3                    RA    RALEIGH    R-6            0.31             71000
# 4                    RA  ST MARY'S   R-10            0.28            152500
#
#   parcel_identification billing_class               property_description  \
# 0   1714.20 81 7084 000   INDIVIDUALS          LO22 LONGVIEW GARDENS BLR
# 1   1722.11 65 9239 000   INDIVIDUALS       LO18 GREEN VALLEY BM1959-315
# 2   1732.13 24 1421 000   INDIVIDUALS  LO17 ROYAL ACRES SUB BM1969-00375
# 3   1723.09 05 4679 000   INDIVIDUALS                 LO26 WORTHDALE SE1
# 4   1702.16 94 4852 000   CORPORATION              LO14-16 EAST PARKLAND
#
#   land_classification      vcs property_index  year_built  units  heated_area  \
# 0                   R  01RA512        01RA512      1964.0      1         1828
# 1                   R  16RA030        16RA030      1970.0      1         1240
# 2                   R  16RA020        16RA020      1970.0      1          976
# 3                   R  01RA500        01RA500      1960.0      1          975
# 4                   R  16RA013        16RA013      1984.0      3         2352
#
#   utilities  year_of_addition  effective_year  remodeled_year  story_height  \
# 0       ALL               NaN          1980.0             NaN           1.0
# 1         E               NaN          1985.0             NaN           1.0
# 2        WE               NaN          1980.0             NaN           1.0
# 3       ALL               NaN          1960.0             NaN           1.0
# 4       ALL               NaN          1984.0             NaN           1.0
#
#   design_style foundation_basement exterior_wall heat air  bath  \
# 0            I                   B             D    A   A   2.0
# 1            A                   C             A    A   A   1.0
# 2            A                   C             A    A   H   1.0
# 3            G                   C             B    A   H   1.0
# 4            A                   C             A    A   A   2.5
#
#   built_in1_description grade  recycled_units disq_and_qual_flag  \
# 0         One Fireplace  C+10               1                  A
# 1                   NaN  C-10               1                  A
# 2                   NaN  C-05               1                  I
# 3                   NaN     C               1                  A
# 4                   NaN  C-10               3                  A
#
#   land_disq_and_qual_flag  type_and_use physical_city  physical_zip_code  \
# 0                     NaN    ONE FAMILY       RALEIGH            27610.0
# 1                     NaN    ONE FAMILY       RALEIGH            27610.0
# 2                     NaN    ONE FAMILY       RALEIGH            27610.0
# 3                     NaN    ONE FAMILY       RALEIGH            27610.0
# 4                     NaN  THREE FAMILY       RALEIGH            27610.0
#
#      physical_location  total_sale_year  total_sale_month  latitude  \
# 0       2457 BERTIE DR           1974.0                 1   35.7577
# 1   2848 PROVIDENCE RD           1983.0                 5   35.7577
# 2  5009 ROYAL ACRES RD           2003.0                 3   35.7577
# 3      2807 CROYDON ST           1999.0                 4   35.7577
# 4       2800 GARNER RD           2017.0                 3   35.7577
#
#    longitude  zipcode  distance_nearest_city nearest_city
# 0   -78.5749    27610                6.21299      RALEIGH
# 1   -78.5749    27610                6.21299      RALEIGH
# 2   -78.5749    27610                6.21299      RALEIGH
# 3   -78.5749    27610                6.21299      RALEIGH
# 4   -78.5749    27610                6.21299      RALEIGH

# %%
house = house.drop(['zipcode', 'latitude', 'longitude'], axis=1)
house.shape
# Out:
# (328075, 43)

# %% [markdown]
# ### 2.4.6 Population and Unemployment

# %%
pop_unemploy = pd.read_csv('../Data/wake_pop_den_unemp_rate_1973_to_now.csv')
pop_unemploy.head()
# Out:
#    year  population_per_square_mile  unemployment_rate
# 0  1973                  296.842547                4.9
# 1  1974                  306.877319                7.2
# 2  1975                  312.011388                8.2
# 3  1976                  318.195608                6.2
# 4  1977                  326.946862                5.9

# %%
house = house.merge(pop_unemploy, left_on='total_sale_year', right_on='year')
house = house.drop('year', axis=1)
house.head()
# Out:
#                            owner1 owner2   mailing_address1  \
# 0  MICKENS, ROBERT EARL & ANNIE M    NaN     2457 BERTIE DR
# 1     TERRELL, WILLIAM M & RUTH H    NaN      46 INDIAN TRL
# 2               HOUSTON, PRINCE L    NaN  816 FRIAR TUCK RD
# 3               NICHOLSON, ROSA J    NaN       3315 BELL DR
# 4             WIMBERLEY, ALFRED G    NaN       PO BOX 27444
#
#         mailing_address2  real_estate_id planning_jurisdiction township  \
# 0  RALEIGH NC 27610-1730              19                    RA  RALEIGH
# 1  SANFORD NC 27332-8384            2694                    RA  RALEIGH
# 2  RALEIGH NC 27610-3633            3021                    RA  RALEIGH
# 3  RALEIGH NC 27610-3760            4929                    RA  RALEIGH
# 4  RALEIGH NC 27611-7444            6064                    RA  RALEIGH
#
#   zoning  deeded_acreage  total_sale_price parcel_identification  \
# 0    R-4            0.21             34500   1714.20 81 7084 000
# 1    R-6            0.30             22500   1723.14 24 6984 000
# 2    R-6            0.28             19500   1713.16 94 6543 000
# 3    R-6            0.30             17000   1723.14 34 4102 000
# 4   R-10            0.13              1500   1713.06 38 0443 000
#
#   billing_class                     property_description land_classification  \
# 0   INDIVIDUALS                LO22 LONGVIEW GARDENS BLR                   R
# 1   INDIVIDUALS                 LO150 WORTHDALE ADDN SE1                   R
# 2   INDIVIDUALS                       LO97 WORTHDALE SE2                   R
# 3   INDIVIDUALS                       LO31 WORTHDALE SE3                   R
# 4   INDIVIDUALS  LO118 RCMB BATTERY HEIGHTS BM2019-00378                   R
#
#        vcs property_index  year_built  units  heated_area utilities  \
# 0  01RA512        01RA512      1964.0      1         1828       ALL
# 1  01RA502        01RA502      1961.0      1         1292       ALL
# 2  01RA500        01RA500      1959.0      1         1125       ALL
# 3  01RA502        01RA502      1963.0      1         1417       ALL
# 4  01RA542        01RA542      2006.0      1         1143       ALL
#
#    year_of_addition  effective_year  remodeled_year  story_height  \
# 0               NaN          1980.0             NaN           1.0
# 1               NaN          1985.0             NaN           1.0
# 2               NaN          1959.0             NaN           1.0
# 3               NaN          1985.0             NaN           1.0
# 4               NaN          2006.0             NaN           1.0
#
#   design_style foundation_basement exterior_wall heat air  bath  \
# 0            I                   B             D    A   A   2.0
# 1            A                   C             B    A   A   2.0
# 2            A                   C             B    A   H   1.0
# 3            A                   C             B    A   A   1.5
# 4            A                   C             Z    A   A   2.0
#
#   built_in1_description grade  recycled_units disq_and_qual_flag  \
# 0         One Fireplace  C+10               1                  A
# 1         One Fireplace     C               1                  A
# 2                   NaN     C               1                  A
# 3         One Fireplace     C               1                  A
# 4         One Fireplace     C               1                  A
#
#   land_disq_and_qual_flag type_and_use physical_city  physical_zip_code  \
# 0                     NaN   ONE FAMILY       RALEIGH            27610.0
# 1                     NaN   ONE FAMILY       RALEIGH            27610.0
# 2                     NaN   ONE FAMILY       RALEIGH            27610.0
# 3                     NaN   ONE FAMILY       RALEIGH            27610.0
# 4                       A   ONE FAMILY       RALEIGH            27610.0
#
#    physical_location  total_sale_year  total_sale_month  \
# 0     2457 BERTIE DR           1974.0                 1
# 1      708 COOPER RD           1974.0                 1
# 2  816 FRIAR TUCK RD           1974.0                 1
# 3       3315 BELL DR           1974.0                 1
# 4    1318 BATTERY DR           1974.0                 1
#
#    distance_nearest_city nearest_city  population_per_square_mile  \
# 0                6.21299      RALEIGH                  306.877319
# 1                6.21299      RALEIGH                  306.877319
# 2                6.21299      RALEIGH                  306.877319
# 3                6.21299      RALEIGH                  306.877319
# 4                6.21299      RALEIGH                  306.877319
#
#    unemployment_rate
# 0                7.2
# 1                7.2
# 2                7.2
# 3                7.2
# 4                7.2

# %%
house.shape
# Out:
# (326112, 45)

# %% [markdown]
# ## 2.5 Review Distribution
# ### 2.5.1 Histgram

# %%
house.hist(figsize=(15, 10))
plt.tight_layout();

# %% [markdown]
# <FONT COLOR=RED> It looks like there are lots of features have asymmeric distribution, lot of outliers.

# %% [markdown]
# ### 2.5.2 Statistic Description

# %%
des = house.describe(include='all')
des
# Out:
#                             owner1            owner2 mailing_address1  \
# count                       326112             67230           326112
# unique                      299669             64089           289659
# top     AC BLACKWOLF RUN OWNER LLC  BRADFORD XIV LLC      PO BOX 4090
# freq                           329                19             1683
# mean                           NaN               NaN              NaN
# std                            NaN               NaN              NaN
# min                            NaN               NaN              NaN
# 25%                            NaN               NaN              NaN
# 50%                            NaN               NaN              NaN
# 75%                            NaN               NaN              NaN
# max                            NaN               NaN              NaN
#
#                 mailing_address2  real_estate_id planning_jurisdiction  \
# count                     326111   326112.000000                326112
# unique                     68642             NaN                    15
# top     SCOTTSDALE AZ 85261-4090             NaN                    RA
# freq                        1683             NaN                125369
# mean                         NaN   257666.557066                   NaN
# std                          NaN   136686.464003                   NaN
# min                          NaN       19.000000                   NaN
# 25%                          NaN   147317.750000                   NaN
# 50%                          NaN   256070.500000                   NaN
# 75%                          NaN   362355.250000                   NaN
# max                          NaN   507212.000000                   NaN
#
#          township  zoning  deeded_acreage  total_sale_price  \
# count      326112  326112   326112.000000      3.261120e+05
# unique         20     245             NaN               NaN
# top     WHITE OAK     R-4             NaN               NaN
# freq        35287   42489             NaN               NaN
# mean          NaN     NaN        0.402383      3.105056e+05
# std           NaN     NaN        1.055448      2.194614e+05
# min           NaN     NaN        0.000000      5.000000e+00
# 25%           NaN     NaN        0.130000      1.650000e+05
# 50%           NaN     NaN        0.230000      2.668000e+05
# 75%           NaN     NaN        0.400000      3.990000e+05
# max           NaN     NaN      128.330000      7.940000e+06
#
#        parcel_identification billing_class property_description  \
# count                 326112        326112               326093
# unique                326106             6               324436
# top      0785.12 85 1079 005   INDIVIDUALS                  LO1
# freq                       2        306781                  100
# mean                     NaN           NaN                  NaN
# std                      NaN           NaN                  NaN
# min                      NaN           NaN                  NaN
# 25%                      NaN           NaN                  NaN
# 50%                      NaN           NaN                  NaN
# 75%                      NaN           NaN                  NaN
# max                      NaN           NaN                  NaN
#
#        land_classification      vcs property_index     year_built  \
# count               326105   326112         326112  326112.000000
# unique                  20     4661           4852            NaN
# top                      R  01RA512        01RA512            NaN
# freq                312588      929            929            NaN
# mean                   NaN      NaN            NaN    1996.600401
# std                    NaN      NaN            NaN      19.653444
# min                    NaN      NaN            NaN    1790.000000
# 25%                    NaN      NaN            NaN    1987.000000
# 50%                    NaN      NaN            NaN    2000.000000
# 75%                    NaN      NaN            NaN    2010.000000
# max                    NaN      NaN            NaN    2023.000000
#
#                 units    heated_area utilities  year_of_addition  \
# count   326112.000000  326112.000000    323952      13950.000000
# unique            NaN            NaN        15               NaN
# top               NaN            NaN       ALL               NaN
# freq              NaN            NaN    242762               NaN
# mean         1.007160    2293.304659       NaN       2016.931971
# std          0.174992    1011.271104       NaN          5.302184
# min          0.000000       0.000000       NaN       1979.000000
# 25%          1.000000    1559.000000       NaN       2014.000000
# 50%          1.000000    2124.000000       NaN       2019.000000
# 75%          1.000000    2825.000000       NaN       2021.000000
# max         14.000000   21993.000000       NaN       2023.000000
#
#         effective_year  remodeled_year   story_height design_style  \
# count    326108.000000     7832.000000  324895.000000       324895
# unique             NaN             NaN            NaN           15
# top                NaN             NaN            NaN            A
# freq               NaN             NaN            NaN       242675
# mean       1999.901652     2016.784729       1.623726          NaN
# std          14.936676        4.639873       0.446585          NaN
# min        1840.000000     1985.000000       1.000000          NaN
# 25%        1991.000000     2015.000000       1.000000          NaN
# 50%        2002.000000     2018.000000       1.880000          NaN
# 75%        2011.000000     2020.000000       2.000000          NaN
# max        2023.000000     2023.000000       3.000000          NaN
#
#        foundation_basement exterior_wall    heat     air           bath  \
# count               326112        324895  324888  324895  324880.000000
# unique                   3            19       6       3            NaN
# top                      C             A       A       A            NaN
# freq                281367        169520  323475  320284            NaN
# mean                   NaN           NaN     NaN     NaN       2.567265
# std                    NaN           NaN     NaN     NaN       0.605766
# min                    NaN           NaN     NaN     NaN       0.000000
# 25%                    NaN           NaN     NaN     NaN       2.500000
# 50%                    NaN           NaN     NaN     NaN       2.500000
# 75%                    NaN           NaN     NaN     NaN       3.000000
# max                    NaN           NaN     NaN     NaN       3.500000
#
#        built_in1_description   grade  recycled_units disq_and_qual_flag  \
# count                 263153  326112   326112.000000             325926
# unique                     2      54             NaN                 19
# top            One Fireplace       B             NaN                  A
# freq                  251875   37006             NaN             302476
# mean                     NaN     NaN        1.006768                NaN
# std                      NaN     NaN        0.214769                NaN
# min                      NaN     NaN        0.000000                NaN
# 25%                      NaN     NaN        1.000000                NaN
# 50%                      NaN     NaN        1.000000                NaN
# 75%                      NaN     NaN        1.000000                NaN
# max                      NaN     NaN       73.000000                NaN
#
#        land_disq_and_qual_flag type_and_use physical_city  physical_zip_code  \
# count                   129894       326112        326112      326112.000000
# unique                      18            4            19                NaN
# top                          A   ONE FAMILY       RALEIGH                NaN
# freq                     79374       323584        148243                NaN
# mean                       NaN          NaN           NaN       27571.611465
# std                        NaN          NaN           NaN          41.759484
# min                        NaN          NaN           NaN       27501.000000
# 25%                        NaN          NaN           NaN       27526.000000
# 50%                        NaN          NaN           NaN       27587.000000
# 75%                        NaN          NaN           NaN       27610.000000
# max                        NaN          NaN           NaN       27713.000000
#
#        physical_location  total_sale_year  total_sale_month  \
# count             326112    326112.000000     326112.000000
# unique            325978              NaN               NaN
# top        403 N MAIN ST              NaN               NaN
# freq                   3              NaN               NaN
# mean                 NaN      2011.628588          6.630679
# std                  NaN        10.242016          3.274409
# min                  NaN      1974.000000          1.000000
# 25%                  NaN      2006.000000          4.000000
# 50%                  NaN      2015.000000          7.000000
# 75%                  NaN      2020.000000          9.000000
# max                  NaN      2023.000000         12.000000
#
#         distance_nearest_city nearest_city  population_per_square_mile  \
# count           326112.000000       326112               326112.000000
# unique                    NaN           18                         NaN
# top                       NaN      RALEIGH                         NaN
# freq                      NaN        79151                         NaN
# mean                 5.967920          NaN                 1087.517694
# std                  3.658676          NaN                  283.678751
# min                  0.449741          NaN                  306.877319
# 25%                  2.260920          NaN                  914.842127
# 50%                  6.212990          NaN                 1193.520571
# 75%                  8.753320          NaN                 1321.172201
# max                 14.375230          NaN                 1397.792350
#
#         unemployment_rate
# count       326112.000000
# unique                NaN
# top                   NaN
# freq                  NaN
# mean             4.432209
# std              1.535351
# min              1.400000
# 25%              3.400000
# 50%              4.100000
# 75%              4.800000
# max              9.200000

# %% [markdown]
# ### 2.5.3 features type

# %%
continuous_features = list(des.columns[des.T['mean'].notna()])
continuous_features
# Out:
# ['real_estate_id',
#  'deeded_acreage',
#  'total_sale_price',
#  'year_built',
#  'units',
#  'heated_area',
#  'year_of_addition',
#  'effective_year',
#  'remodeled_year',
#  'story_height',
#  'bath',
#  'recycled_units',
#  'physical_zip_code',
#  'total_sale_year',
#  'total_sale_month',
#  'distance_nearest_city',
#  'population_per_square_mile',
#  'unemployment_rate']

# %%
categorical_features = list(set(house.columns) - set(continuous_features))
categorical_features
# Out:
# ['land_classification',
#  'utilities',
#  'physical_city',
#  'disq_and_qual_flag',
#  'planning_jurisdiction',
#  'owner2',
#  'township',
#  'foundation_basement',
#  'nearest_city',
#  'heat',
#  'parcel_identification',
#  'type_and_use',
#  'mailing_address2',
#  'exterior_wall',
#  'built_in1_description',
#  'vcs',
#  'land_disq_and_qual_flag',
#  'air',
#  'property_index',
#  'owner1',
#  'grade',
#  'property_description',
#  'billing_class',
#  'physical_location',
#  'zoning',
#  'mailing_address1',
#  'design_style']

# %%
for i in categorical_features:
    print(i)
    print(house[i].unique(), '\n')
# Out:
# land_classification
# ['R' 'H' 'N' 'F' 'P' 'E' 'B' 'Y' 'G' 'O' 'C' 'K' 'L' nan 'Z' 'V' 'D' 'I'
#  'A' 'T' 'M']
#
# utilities
# ['ALL' 'E' 'WE' nan 'WSE' 'WGE' 'SE' 'GE' 'G' 'WS' 'WSG' 'W' 'S' 'SGE'
#  'WG' 'SG']
#
# physical_city
# ['RALEIGH' 'WENDELL' 'CARY' 'KNIGHTDALE' 'FUQUAY VARINA' 'GARNER' 'APEX'
#  'WAKE FOREST' 'HOLLY SPRINGS' 'ZEBULON' 'WILLOW SPRING' 'MORRISVILLE'
#  'ROLESVILLE' 'NEW HILL' 'CLAYTON' 'YOUNGSVILLE' 'CREEDMOOR' 'ANGIER'
#  'DURHAM']
#
# disq_and_qual_flag
# ['A' 'T' nan 'E' 'I' 'U' 'F' 'D' 'C' 'S' 'K' 'N' 'P' 'L' 'R' 'V' 'O' 'G'
#  'J' 'H']
#
# planning_jurisdiction
# ['RA' 'WC' 'KN' 'WE' 'CA' 'MO' 'FV' 'GA' 'AP' 'WF' 'HS' 'ZB' 'RO' 'AN'
#  'DU']
#
# owner2
# [nan 'WARREN, EARL N' 'HORTON, PATRICE' ... 'MALONEY, JOSEPHINE BURCHETTE'
#  'BLACK, SHERRY LYNN' 'MOHR, KIMBERLY A TRUSTEE']
#
# township
# ['RALEIGH' "ST MARY'S" "ST MATTHEW'S" "MARK'S CREEK" 'SWIFT CREEK'
#  'LEESVILLE' "BARTON'S CREEK" 'CARY' 'MEREDITH' 'HOUSE CREEK' 'NEUSE'
#  'CEDAR FORK' 'MIDDLE CREEK' 'HOLLY SPRING' 'PANTHER BRANCH' 'WHITE OAK'
#  'BUCKHORN' 'WAKE FOREST' 'LITTLE RIVER' 'NEW LIGHT']
#
# foundation_basement
# ['B' 'C' 'A']
#
# nearest_city
# ['RALEIGH' 'WENDELL' 'CARY' 'KNIGHTDALE' 'FUQUAY VARINA' 'GARNER' 'APEX'
#  'WAKE FOREST' 'HOLLY SPRINGS' 'ZEBULON' 'WILLOW SPRING' 'ROLESVILLE'
#  'NEW HILL' 'CLAYTON' 'YOUNGSVILLE' 'CREEDMOOR' 'ANGIER' 'DURHAM']
#
# heat
# ['A' 'I' 'J' nan 'H' 'L' 'G']
#
# parcel_identification
# ['1714.20 81 7084 000' '1723.14 24 6984 000' '1713.16 94 6543 000' ...
#  '0733.02 99 3454 000' '0733.02 99 3558 000' '0675.03 20 0858 000']
#
# type_and_use
# ['ONE FAMILY' 'TWO FAMILY' 'THREE FAMILY' 'FOUR FAMILY']
#
# mailing_address2
# ['RALEIGH NC 27610-1730' 'SANFORD NC 27332-8384' 'RALEIGH NC 27610-3633'
#  ... 'WAKE FOREST NC 27588-1315' 'CARY NC 27519-6605'
#  'ANGIER NC 27501-9569']
#
# exterior_wall
# ['D' 'B' 'Z' 'A' 'C' 'G' 'L' 'Q' 'I' 'J' 'R' 'H' 'K' nan 'F' 'O' 'E' 'Y'
#  'N' 'X']
#
# built_in1_description
# ['One Fireplace' nan 'Multiple Firepl']
#
# vcs
# ['01RA512' '01RA502' '01RA500' ... '01RA733' '05MO999' '12WC03P']
#
# land_disq_and_qual_flag
# [nan 'A' 'T' 'C' 'E' 'L' 'R' 'I' 'D' 'V' 'S' 'F' 'P' 'K' 'J' 'O' 'N' 'G'
#  'H']
#
# air
# ['A' 'H' 'G' nan]
#
# property_index
# ['01RA512' '01RA502' '01RA500' ... 'MORRISVILLE COMMUNITY PARK' 'LYNBROOK'
#  '12WC03P']
#
# owner1
# ['MICKENS, ROBERT EARL & ANNIE M' 'TERRELL, WILLIAM M & RUTH H'
#  'HOUSTON, PRINCE L' ... 'BLACK, GARY WHITSON' 'MOHR, JEFFREY P TRUSTEE'
#  'BEAL, JOYCE I']
#
# grade
# ['C+10' 'C' 'C-05' 'C+05' 'C-10' 'B' 'D+05' 'D+10' 'B-05' 'B+05' 'A-05'
#  'A-10' 'B+10' 'A' 'B-10' 'AA-10' 'A+10' 'AA' 'D' 'A+20' 'A+05' 'A+25' 'E'
#  'E+10' 'D-10' 'D-20' 'A+15' 'AA+15' 'AA+20' 'AA+10' 'AA-05' 'D-05'
#  'AA-15' 'AA+05' 'AA+30' 'AA+50' 'AA+60' 'AA+25' '0' 'E-10' 'AA+40' 'E-15'
#  'E+15' 'D-15' 'AA+85' 'AA+90' 'AA+80' 'AA+70' 'E-50' 'E+05' 'E-20' 'E-25'
#  'E-30' 'E-05']
#
# property_description
# ['LO22 LONGVIEW GARDENS BLR' 'LO150 WORTHDALE ADDN SE1'
#  'LO97 WORTHDALE SE2' ... 'LO93 PARKMEADOW SUB PH1 SC2 BM1990-1190'
#  'LO113 PARKMEADOW SUB PH1 SC2 BM1991-1042'
#  'LO35 KENNEBEC ACRES SE2 BM1984-01402']
#
# billing_class
# ['INDIVIDUALS' 'LIFE ESTATE' 'CORPORATION' 'EXEMPT' 'HOA' 'PUBLIC SERVICE']
#
# physical_location
# ['2457 BERTIE DR' '708 COOPER RD' '816 FRIAR TUCK RD' ...
#  '307 PARKMEADOW DR' '306 PARKMEADOW DR' '8208 OAKCLIFF LN']
#
# zoning
# ['R-4' 'R-6' 'R-10' 'R-30' 'RT' 'R2' 'NC' 'R-20' 'R-40' 'RR' 'R-40W'
#  'OX-3' 'R-80W' 'R-2' 'R20' 'R-1' 'R12' 'LDR' 'RMF' 'R12P' 'GR3' 'GR8'
#  'RR1' 'RA' 'R4' 'NMX' 'CMX' 'HD' 'MF-A' 'LD' 'MD' 'UR' 'GR5' 'R-15' 'DTP'
#  'HCV' 'R40' 'R3' 'RX-3' 'NX-3' 'RMFP' 'TR' 'TRP' 'R8P' 'R8' 'RLD' 'RMD'
#  'O&I' 'DC-1' 'RMD-CZD' 'RX-4' 'MORR-CU' 'RL' 'PUD-CZ' 'PC-CU' 'CX-12'
#  'OX-5' 'R40-C' 'CM' 'PD' 'CX-3' 'OX-4' 'R20P' 'TRCU' 'R8CU' 'R8-C'
#  'R12CU' 'RMX' 'UR12' 'CU-R-30' 'CU-R-20' 'CU-R-10' 'RHD' 'PUD' 'RHD-CZD'
#  'HD SF' 'HD MF' 'HD SF-CU' 'MD-CU' 'HD MF-CU' 'TND-CU' 'DX-7' 'DX-3'
#  'CU-R-15' 'GR10' 'DX-12' 'R-8' 'R-MF-8' 'R6' 'OI' 'RM-CZ' 'RM' 'R&PUD'
#  'SIA' 'B1' 'R12-C' 'HDR' 'MDR' 'RMF-C' 'GCP' 'HB' 'TC' 'DC-2' 'ICD' 'RD'
#  'LI' 'GB' 'R1' 'R40P' 'RM12P' 'PUD-15-1' 'OIP' 'RMFM' 'TRM' 'C-MDR'
#  'ORDP' 'RLD-CZD' 'MF-1' 'CB' 'PUD-CU' 'LD-CU' 'MD-CZ' 'LD-CZ' 'HD MF-CZ'
#  'HD SF-CZ' 'DX-5' 'DX-40' 'DX-20' 'UMX' 'GC' 'CX-4' 'NX-7' 'CUD BUS'
#  'R-10 CU' 'R-8 CU' 'R-10CU' 'R-MF-15' 'R-13-SUD' 'R2-CZ' 'AP' 'R8M'
#  'R20CU' 'MS' 'TCR' 'ORD' 'RNP' 'VLDR' 'RMFCU' 'NAC' 'R20M' 'PDR-HDR'
#  'TBD' 'HI' 'TCC' 'MH' 'DMX' 'R7-CD' 'R2-CD' 'R7' 'NX-5' 'IX-3' 'HBCD'
#  'NMU' 'RA-CZD' 'PRD' 'R-9' 'OS' 'TV' 'LB' 'R-80' 'R-15 CU' 'HC' 'R2-SUD'
#  'R-6 CU' 'CX-5' 'R40CU' 'O&I-CZ' 'OIM' 'RA-30' 'MI' 'LB LIMITED' 'CC'
#  'R12M' 'R3CU' 'IP' 'RLI' 'MORR-CZ' 'B2' 'MH-CU' 'UK' 'R-MF-8 CU' 'R-13'
#  'R-I' 'CH' 'C-HDR' 'CUD R-6' 'NX-4' 'LB CU' 'C-W' 'R1-SUD' 'CUD R-10'
#  'R/RM' 'I-2' 'CUD R-4' 'RX-5' 'OICU' 'NC-CZD' 'I-I' 'CX-20' 'CB CU'
#  'GC-CZ' 'R-1-CU' 'B1-CZ' 'TOD' 'OX-7' 'MHO' 'RMF-SUD' 'TF-CZ' 'PC-CZ'
#  'R/RP' 'RS-10' 'RA HC' 'GR5 (PUD)' 'CU GR5' 'RMH-8' 'R40W' 'C-RT' 'CBD'
#  'CUD O&I-1' 'GCM' 'GCCU' 'IH' 'B1-CU' 'NB' 'CU-HC' 'B2-CU' 'MUPD' 'O&I-1'
#  'SD-CZ' 'RAC' 'R-12' 'OX-12' 'CUD R-20' 'I-1' 'O&I-CU']
#
# mailing_address1
# ['2457 BERTIE DR' '46 INDIAN TRL' '816 FRIAR TUCK RD' ...
#  '307 PARKMEADOW DR' '306 PARKMEADOW DR' '8208 OAKCLIFF LN']
#
# design_style
# ['I' 'A' 'G' 'O' 'J' 'K' 'E' 'B' 'C' 'D' 'L' 'F' nan 'H' 'N' 'M']

# %%
house.head(2)
# Out:
#                            owner1 owner2 mailing_address1  \
# 0  MICKENS, ROBERT EARL & ANNIE M    NaN   2457 BERTIE DR
# 1     TERRELL, WILLIAM M & RUTH H    NaN    46 INDIAN TRL
#
#         mailing_address2  real_estate_id planning_jurisdiction township  \
# 0  RALEIGH NC 27610-1730              19                    RA  RALEIGH
# 1  SANFORD NC 27332-8384            2694                    RA  RALEIGH
#
#   zoning  deeded_acreage  total_sale_price parcel_identification  \
# 0    R-4            0.21             34500   1714.20 81 7084 000
# 1    R-6            0.30             22500   1723.14 24 6984 000
#
#   billing_class       property_description land_classification      vcs  \
# 0   INDIVIDUALS  LO22 LONGVIEW GARDENS BLR                   R  01RA512
# 1   INDIVIDUALS   LO150 WORTHDALE ADDN SE1                   R  01RA502
#
#   property_index  year_built  units  heated_area utilities  year_of_addition  \
# 0        01RA512      1964.0      1         1828       ALL               NaN
# 1        01RA502      1961.0      1         1292       ALL               NaN
#
#    effective_year  remodeled_year  story_height design_style  \
# 0          1980.0             NaN           1.0            I
# 1          1985.0             NaN           1.0            A
#
#   foundation_basement exterior_wall heat air  bath built_in1_description  \
# 0                   B             D    A   A   2.0         One Fireplace
# 1                   C             B    A   A   2.0         One Fireplace
#
#   grade  recycled_units disq_and_qual_flag land_disq_and_qual_flag  \
# 0  C+10               1                  A                     NaN
# 1     C               1                  A                     NaN
#
#   type_and_use physical_city  physical_zip_code physical_location  \
# 0   ONE FAMILY       RALEIGH            27610.0    2457 BERTIE DR
# 1   ONE FAMILY       RALEIGH            27610.0     708 COOPER RD
#
#    total_sale_year  total_sale_month  distance_nearest_city nearest_city  \
# 0           1974.0                 1                6.21299      RALEIGH
# 1           1974.0                 1                6.21299      RALEIGH
#
#    population_per_square_mile  unemployment_rate
# 0                  306.877319                7.2
# 1                  306.877319                7.2

# %% [markdown]
# ### 2.5.4 Output File

# %%
house.to_csv('../Data/house_Jan24_2024.csv')

# %% [markdown]
# ## 2.6 Conclusion
# ### 2.6.1 Data Cleaning
#
# 1. check the shape and columns of the dataset, use all lower case for column names for uniformity.
# 2. check the target variable total_sale_price and total_sale_date, do operations like remove comma, change to numeric, drop nan rows and drop value=0 rows.
# 3. combine variables related to street like street_number, street_prefix, street_name, street_type etc. to get physical location, and check physical_zip_code to remove nan and value=0 rows.
# 4. check duplicates in two ways:
# 4.1 use physical_location and physical_zip_code to remove duplicates.
# 4.2 use real_estate_id to remove duplicates.
# 5. check other price variables' format, remove comma and change to numeric.
# 6. check data variables' format, change to datetime, extract year and month.
# 7. correct obviously wrong input in datetime, like 2056, 2066, 2070,  207 etc.
# 8. drop variables with missing percentage >95%.
# 9. check variable dtypes, change some variables from categorical to numeric
# 10. drop some useless variables.
# 11. although submitted this notebook as data wrangling of capstone two. but the data wangling process are not over at all, we will keep doing data wrangling through the whole project
#
# ### 2.6.2 Data Manipulation
# 1. merge with downtown longitude and latitude data.
# 2. merge with population and unemployment data.
